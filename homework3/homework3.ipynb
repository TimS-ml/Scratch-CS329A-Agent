# %% [markdown]
# # Stanford CS 329a Self-Improving AI Agents, Homework 3
#
# This assignment builds an end-to-end agentic workflow by combining LLMs with external APIs and self-improvement techniques.
#
# - **Part 1:** Implementing an API-augmented LLM pipeline which integrates four external APIs, and generates responses grounded in API responses.
# - **Part 2:** Applying self-improvement methods:
#   - Query decomposition & fusion: Breaks complex queries into sub-queries, retrieves API outputs, and fuses the results.
#   - Iterative refinement: Uses the LLM to trigger additional API calls and refine the response until sufficient information is gathered to answer the query.
# - **Part 3:** Integrating these components into a full agentic workflow and evaluating accuracy on the test set.
# - **Part 4:** Extending the system into a deep research agent for knowledge-intensive tasks, inspired by recent AI launches.
#
# **Final Deliverable**: A zipped folder (.zip) of your edited files.

# %%
# Auto-reloads imported modules, so changes to .py files are automatically reflected in the notebook
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Package Installation

# %% [markdown]
# #### API Configuration and Setup
#
# Before we can use the APIs, we need to set up our environment and initialize the API manager. This involves:
#
# 1. Loading API keys from environment variables
# 2. Setting up the API manager with the necessary credentials
# 3. Validating that all required keys are present
#
# For this homework, we'll use:
# - Google Custom Search API (requires API key and Custom Search Engine ID):
#      - https://developers.google.com/custom-search/v1/overview
#      - https://programmablesearchengine.google.com/controlpanel/create
#        -  Once created, the Custom Search Engine ID can be found here: https://programmablesearchengine.google.com/controlpanel/all
# - Polygon API (requires API key):
#      - https://polygon.io/dashboard/keys
# - Wolfram Alpha API (requires app ID):
#      - https://developer.wolframalpha.com/access
#
# **Note**: Be mindful of your API usage and compute budget. Use smaller, more cost-effective models (e.g. gemma-3n-E4B-it) for development before scaling to larger models. For security, never hardcode API keys; always use a `.env` file and add it to your `.gitignore`.

# %%
import os
from dotenv import load_dotenv
from cs329a_hw3.api_manager import APIManager

# Load environment variables from .env file (keys are also read from the shell env)
load_dotenv()

# Get API keys
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')      # optional -> DuckDuckGo fallback
GOOGLE_CX_ID = os.getenv('GOOGLE_CX_ID')          # optional -> DuckDuckGo fallback
POLYGON_API_KEY = os.getenv('POLYGON_API_KEY')
WOLFRAM_APP_ID = os.getenv('WOLFRAM_APP_ID')
# NB: LLM calls are routed to Anthropic/OpenAI/Gemini via litellm (see utils.py),
# so TOGETHER_API_KEY is not required.

if not all([POLYGON_API_KEY, WOLFRAM_APP_ID]):
    raise ValueError("POLYGON_API_KEY and WOLFRAM_APP_ID are required (set them in .env)")
if not (GOOGLE_API_KEY and GOOGLE_CX_ID):
    print("Note: Google Custom Search keys not set -> using DuckDuckGo fallback for web search.")

api_manager = APIManager(
    google_api_key=GOOGLE_API_KEY,
    google_cx_id=GOOGLE_CX_ID,
    polygon_api_key=POLYGON_API_KEY,
    wolfram_app_id=WOLFRAM_APP_ID
)

print("APIManager initialized successfully.")
# Out:
# Note: Google Custom Search keys not set -> using DuckDuckGo fallback for web search.
# APIManager initialized successfully.

# %% [markdown]
# ## Part 0 - LLM Performance with a Single Call [5 points]
#
# To establish a baseline, let's test the performance of a standalone Large Language Model (LLM) without any external tools or APIs. This helps illustrate the limitations of relying solely on the model's internal knowledge, especially for questions requiring real-time, specific, or computational information.
#
# **Deliverable:**
# - In the `cs329a_hw3/multi_lm_agent.py` file, implement the `generate` method in the MultiLMAgent class.
#
# **Observe that:**
# - LLMs can hallucinate or provide outdated information for fact-based queries.
# - Models often struggle with precise mathematical calculations that a tool like Wolfram Alpha can solve instantly, due to the tokenization scheme.
# - Queries about current stock prices or today's weather are outside the scope of a model's static training data.
# - Evaluation is difficult for unstructured model outputs. Numerical answers have multiple possible formats, which makes naive string-matching unreliable; and natural language answers can be phrased in various ways. To that end, we've provided a `evaluate_qa` function that uses a fast, cheap model (gemma-3n-E4B-it) to more reliably evaluate the model's output.

# %%
from cs329a_hw3.multi_lm_agent import MultiLMAgent
from cs329a_hw3.evaluation import prepare_dataset, evaluate_qa

multi_lm_agent = MultiLMAgent(api_manager)
dataset = prepare_dataset(debug_mode=False)

queries, answers = dataset['query'], dataset['answer']
num_correct = 0
print("Zero-Shot Responses:")
zero_shot_responses = []
for query, answer in zip(queries, answers):
    response = multi_lm_agent.generate(query=query, model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo")
    zero_shot_responses.append(response)
    print(f"Query: {query}")
    print(f"Zero-Shot Response: {response}")
    print(f"Answer: {answer}")
    is_correct = evaluate_qa(query, response, answer, model="google/gemma-3n-E4B-it")
    num_correct += is_correct
    print("Is Correct:", is_correct)
    print("-" * 50)

accuracy_zero_shot = num_correct / len(queries)
print(f"Accuracy = {accuracy_zero_shot*100:.1f}%")
# Out:
# Zero-Shot Responses:
# Query: Were there any thunderstorms in Seattle, WA at noon on June 1st, 2025?
# Zero-Shot Response: I don't have access to real-time weather data or historical weather records for future dates. June 1st, 2025 is in the future, so I cannot tell you whether there were thunderstorms in Seattle at that time.
#
# If you're looking for weather information, I'd recommend:
# - **Weather.com** or **Weather.gov** for current/forecast conditions
# - **NOAA** for historical weather data (for past dates)
# - Local Seattle news sources for regional weather reports
#
# Is there something else I can help you with?
# Answer: No
# Is Correct: False
# --------------------------------------------------
# Query: Which city was windier on August 1, 2025: Chicago or Boston?
# Zero-Shot Response: I don't have access to real-time weather data or historical weather records for August 1, 2025. Since that date is in the future from my knowledge cutoff in April 2024, I cannot tell you which city was windier on that specific date.
#
# To find this information, you could check:
# - Weather history websites (like Weather Underground or NOAA)
# - Local weather archives for Chicago and Boston
# - Historical weather databases
#
# If you're asking about a past date or need current weather information, please let me know and I can try to help differently.
# Answer: Boston
# Is Correct: False
# --------------------------------------------------
# Query: Over the first three days of August 2025, did the morning (9AM) temperature in Miami ever drop below 70 Fahrenheit?
# Zero-Shot Response: I don't have access to real-time weather data or historical weather records for August 2025. Since August 2025 is in the future from my knowledge cutoff date (April 2024), I cannot provide information about actual temperatures that occurred during those dates.
#
# To find this information, you could check:
# - Weather history websites like Weather Underground or NOAA
# - Local Miami weather services
# - Weather archives that maintain historical records
#
# If you're asking this question after August 2025 has already passed, those sources would have the actual recorded data.
# Answer: No
# Is Correct: False
# --------------------------------------------------
# Query: Did Tesla (TSLA) stock go up or down on March 5, 2025 compared to its opening price on that day?
# Zero-Shot Response: I don't have access to real-time or future stock market data. My knowledge was last updated in April 2024, so I cannot provide information about Tesla's stock performance on March 5, 2025.
#
# To find this information, you can check:
# - Financial websites like Yahoo Finance, Google Finance, or Bloomberg
# - Your brokerage account
# - Tesla's investor relations page
#
# These sources will show you the opening and closing prices for any trading day.
# Answer: up
# Is Correct: False
# --------------------------------------------------
# Query: From 4 Nov 2024 to 6 Nov 2024 inclusive (the two days around the U.S. election), what was the change in Tesla closing stock price, rounded to the nearest percent?
# Zero-Shot Response: I don't have access to real-time stock data or historical data beyond April 2024. To find Tesla's stock price change from November 4-6, 2024, I recommend checking:
#
# - **Yahoo Finance** (finance.yahoo.com)
# - **Google Finance** (google.com/finance)
# - **Bloomberg** (bloomberg.com)
# - **Your broker's website**
#
# These sources will show you Tesla's closing prices for those specific dates so you can calculate the percentage change.
# Answer: 19
# Is Correct: False
# --------------------------------------------------
# Query: If Tesla's closing price on Aug 27, 2025 increased by 11.2%, what would that be, to the nearest cent?
# Zero-Shot Response: I don't have access to real-time or future data, including Tesla's closing price on August 27, 2025. That date is in the future, and stock prices cannot be predicted.
#
# If you have Tesla's actual closing price from that date and want to calculate an 11.2% increase, I'd be happy to help with the math. Just provide the price and I can calculate it for you.
# Answer: 388.76
# Is Correct: False
# --------------------------------------------------
# Query: A random variable X has probability density function proportional to cos(x)/sqrt(x) from 1 to 2. What is the normalization constant should this be multiplied by to make this a valid PDF? Round your answer to the nearest integer.
# Zero-Shot Response: I need to find the normalization constant for the PDF proportional to cos(x)/√x on [1,2].
#
# For a valid PDF, we need:
# $$\int_1^2 c \cdot \frac{\cos(x)}{\sqrt{x}} dx = 1$$
#
# where c is the normalization constant.
#
# Therefore:
# $$c = \frac{1}{\int_1^2 \frac{\cos(x)}{\sqrt{x}} dx}$$
#
# Let me evaluate the integral $I = \int_1^2 \frac{\cos(x)}{\sqrt{x}} dx$.
#
# Using numerical integration (this integral doesn't have a closed form in elementary functions):
#
# Let me compute this carefully:
# - At x = 1: cos(1)/√1 ≈ 0.5403/1 ≈ 0.5403
# - At x = 2: cos(2)/√2 ≈ -0.4161/1.414 ≈ -0.2942
#
# Using numerical integration methods (Simpson's rule or similar):
# $$I = \int_1^2 \frac{\cos(x)}{\sqrt{x}} dx \approx 0.0886$$
#
# Therefore, the normalization constant is:
# $$c = \frac{1}{0.0886} \approx 11.29$$
#
# Rounded to the nearest integer: **11**
# Answer: 13
# Is Correct: False
# --------------------------------------------------
# Query: Find the real solution to x^3 = x^5 + 100. Give your answer to the nearest hundredth.
# Zero-Shot Response: I need to find the real solution to $x^3 = x^5 + 100$.
#
# Rearranging:
# $$x^3 - x^5 = 100$$
# $$x^3(1 - x^2) = 100$$
#
# Let me rearrange this as:
# $$x^5 - x^3 + 100 = 0$$
#
# To find the solution numerically, I'll analyze the function $f(x) = x^5 - x^3 + 100$.
#
# **Finding the approximate location:**
#
# - $f(-3) = (-3)^5 - (-3)^3 + 100 = -243 + 27 + 100 = -116$ (negative)
# - $f(-2) = (-2)^5 - (-2)^3 + 100 = -32 + 8 + 100 = 76$ (positive)
#
# So there's a root between $-3$ and $-2$.
#
# - $f(-2.5) = (-2.5)^5 - (-2.5)^3 + 100 = -97.66 + 15.625 + 100 = 17.96$ (positive)
# - $f(-2.7) = (-2.7)^5 - (-2.7)^3 + 100 = -143.49 + 19.68 + 100 = -23.81$ (negative)
#
# The root is between $-2.7$ and $-2.5$.
#
# - $f(-2.6) = (-2.6)^5 - (-2.6)^3 + 100 = -118.81 + 17.58 + 100 = -1.23$ (negative)
# - $f(-2.55) = (-2.55)^5 - (-2.55)^3 + 100 = -108.02 + 16.58 + 100 = 8.56$ (positive)
#
# The root is between $-2.6$ and $-2.55$.
#
# - $f(-2.58) = (-2.58)^5 - (-2.58)^3 + 100 = -113.21 + 17.17 + 100 = 3.96$ (positive)
# - $f(-2.59) = (-2.59)^5 - (-2.59)^3 + 100 = -115.53 + 17.37 + 100 = 1.84$ (positive)
# - $f(-2.595) = (-2.595)^5 - (-2.595)^3 + 100 = -116.68 + 17.47 + 100 = 0.79$ (positive)
# - $f(-2.597) = (-2.597)^5 - (-2.597)^3 + 100 = -117.09 + 17.51 + 100 = 0.42$ (positive)
# - $f(-2.599) = (-2.599)^5 - (-2.599)^3 + 100 = -117.50 + 17.56 + 100 = 0.06$ (positive)
# - $f(-2.6001) = (-2.6001)^5 - (-2.6001)^3 + 100 ≈ -117.52 + 17.57 + 100 = 0.05$ (positive)
# - $f(-2.601) = (-2.601)^5 - (-2.601)^3 + 100 = -117.73 + 17.58 + 100 = -0.15$ (negative)
#
# The root is between $-2.601$ and $-2.599$.
#
# Using linear interpolation: $x ≈ -2.60$
#
# **The answer to the nearest hundredth is $\boxed{-2.60}$**
# Answer: -2.59
# Is Correct: False
# --------------------------------------------------
# Query: Calculate the area of a rectangle with length 123.45 cm and width 67.89 cm, then convert the result to square inches to the nearest integer.
# Zero-Shot Response: # Rectangle Area Calculation
#
# **Step 1: Calculate area in square centimeters**
# - Area = length × width
# - Area = 123.45 cm × 67.89 cm
# - Area = 8,379.68 cm²
#
# **Step 2: Convert to square inches**
# - Conversion factor: 1 inch = 2.54 cm, so 1 in² = 6.4516 cm²
# - Area = 8,379.68 cm² ÷ 6.4516 cm²/in²
# - Area = 1,298.54 in²
#
# **Answer: 1,299 square inches** (rounded to nearest integer)
# Answer: 1299
# Is Correct: True
# --------------------------------------------------
# Query: What 2024 Beyoncé album broke streaming records with its blend of country-pop and Americana?
# Zero-Shot Response: "Cowboy Carter" is the 2024 Beyoncé album that broke streaming records with its country-pop and Americana sound. Released in March 2024, it was her eighth studio album and marked a significant shift toward country and Americana influences.
# Answer: Cowboy Carter
# Is Correct: True
# --------------------------------------------------
# Query: What is the title of the next Avatar film, scheduled for release on December 19, 2025?
# Zero-Shot Response: The next Avatar film scheduled for release on December 19, 2025, is **Avatar: Fire and Ash**.
# Answer: Fire and Ash
# Is Correct: False
# --------------------------------------------------
# Query: How many restaurants in San Francisco have three Michelin stars in 2025?.
# Zero-Shot Response: I don't have access to current 2025 Michelin Guide data, as my knowledge was last updated in April 2024.
#
# As of my last update, San Francisco had **3 three-Michelin-star restaurants**:
# - The French Laundry (technically in Yountville, in the Bay Area)
# - Atelier Crenn
# - Quince
#
# However, Michelin Guide ratings can change annually, and new guides are released each year. For the most current and accurate information about 2025 three-star restaurants in San Francisco, I recommend:
#
# 1. Visiting the official **Michelin Guide website** (guide.michelin.com)
# 2. Checking recent restaurant news from local San Francisco publications
# Answer: Three
# Is Correct: True
# --------------------------------------------------
# Query: What is the name of the restaurant in Palo Alto with a Michelin star in 2025?
# Zero-Shot Response: I don't have access to current information about 2025 Michelin star ratings for restaurants in Palo Alto. Michelin guide ratings are updated annually and my knowledge was last updated in April 2024.
#
# To find this information, I'd recommend:
# 1. Visiting the official Michelin Guide website
# 2. Checking recent restaurant review articles from food publications
# 3. Searching for "Palo Alto Michelin star restaurants 2025"
#
# If you're looking for a specific restaurant or have other questions about Palo Alto dining, I'd be happy to help with what I do know!
# Answer: Protégé
# Is Correct: False
# --------------------------------------------------
# Query: When does Zareen's (Palo Alto) open on Saturday? Format your answer as HH:MM AM/PM
# Zero-Shot Response: I don't have access to current business hours for Zareen's in Palo Alto. To find their Saturday opening time, I recommend:
#
# 1. Visiting their official website
# 2. Checking Google Maps
# 3. Calling them directly
# 4. Looking at their social media pages
#
# This will give you the most accurate and up-to-date information.
# Answer: 11:00 AM
# Is Correct: False
# --------------------------------------------------
# Query: What nationality is the player who won the 2025 men's Wimbledon championship?
# Zero-Shot Response: I don't have access to current information about the 2025 Wimbledon championship results. My knowledge was last updated in April 2024, so I cannot tell you who won the 2025 men's Wimbledon championship.
#
# To find this information, I'd recommend checking:
# - The official Wimbledon website
# - Major sports news outlets
# - Sports databases like ESPN or BBC Sport
# Answer: Italian
# Is Correct: False
# --------------------------------------------------
# Accuracy = 20.0%

# %% [markdown]
# ## Part 1 - API-augmented LLM pipeline [40 points]
#
# In this part, we augment the LLM with four different API calls, then implement an LLM-based API router that routes the query to the appropriate API, and then prompt the LLM to generate the final response given the API outputs.
#
# We will work with the following APIs and select the appropriate API for a given query:
#
# 1. **Google Custom Search API** - For web search
# 2. **Polygon API** - For financial data
# 3. **Wolfram Alpha API** - For mathematical calculations
# 4. **Weather API** - For location-based weather data

# %% [markdown]
# #### 1a. Google Custom Search API [5 points]
#
# The Google Custom Search API allows us to programmatically search the web. We'll use this to gather information and context for our tasks.
#
# Key features:
# - Web search with customizable parameters
# - Filtering and sorting options
# - Rich metadata about search results
#
# Deliverable: In the ``cs329_hw3/api_manager.py`` file, implement the `_extract_webpage_content` and ``google_search`` functions.
#
# **Note**: The `google_search` function will return long webpages, so we will need to truncate or parse the response to get the relevant information. Otherwise, the added context will exceed the context window of the LMs in later functions.

# %%
search_query = "Apple Product News"
results = api_manager.google_search(
    search_query=search_query,
    num_results=3
)

print("\nSearch results for:", search_query)
print("-" * 50)
for i, result in enumerate(results, 1):
    print(f"Result {i}:")
    for k, v in result.items():
        print(f"\t{k}: {v}")
    print("-" * 50)
# Out:
# Search results for: Apple Product News
# --------------------------------------------------
# Result 1:
# 	title: Newsroom - Apple
# 	link: https://www.apple.com/newsroom/
# 	snippet: Apple teams came together to find an innovative way to 3D-print titanium Apple ... Stay up to date with the latest articles from Apple Newsroom.
# 	content: Newsroom - Apple opens in new window Newsroom Stay up to date with the latest articles from Apple Newsroom. Dismiss Get Notifications
# --------------------------------------------------
# Result 2:
# 	title: Apple
# 	link: https://www.apple.com/
# 	snippet: To access and use all Apple Card features and products available only to Apple Card users, you must add Apple Card to Wallet on an iPhone or iPad ...
# 	content: Apple Apple Father’s Day It’s not too late to find the perfect gift. Shop Apple for College Mac and iPad. Major in any field. Learn more iPhone Meet the latest iPhone lineup. Learn more Shop iPhone MacBook Air Now supercharged by M5. Learn more Buy iPad Air Now supercharged by M4. Learn more Buy Apple Privacy That's iPhone. Learn more MacBook Pro Now with M5, M5 Pro, and M5 Max. Learn more Buy Apple Trade In Get up to $195–$695 in credit when you trade in iPhone 13 or higher. 1 Get your estimate Apple Card Get up to 3% Daily Cash back with every purchase. Learn more Apply now Endless entertainment. Item 1 Item 2 Item 3 Item 4 Item 5 Item 6 Item 7 Item 8 Item 9 See the schedule Live MLB games, every Friday. Stream now Drama New season. F1 on Apple TV Every Grand Prix™, live and on demand—all in one place, all year long. Stream now Thriller Fear takes hold. MLS on Apple TV Watch every club, every match, live—all season long. Stream now Mystery Welcome to the island, please enjoy your stay. Just don’t ask too many questions. Stream now Drama Is it a crime to want more? Stream now Thriller A soccer mom falls down a rabbit hole of blackmail and murder. Stream now Comedy Everyone’s got a side hustle. Play now Hello Kitty Island Adventure Sabrina Carpenter: The Zane Lowe Interview Listen now Sabrina Carpenter: The Zane Lowe Interview Watch now 30 Days of Gratitude and Kindness Play now PowerWash Simulator A-List Pop Listen now A-List Pop Watch now Strength with Jenn • Music by Davido Play now SpongeBob: Patty Pursuit 2 New Music Daily Listen now New Music Daily Watch now Asian-Pacific American Heritage Month
# --------------------------------------------------
# Result 3:
# 	title: Apple launches Apple News+, an immersive magazine and news
# 	link: https://www.apple.com/newsroom/2019/03/apple-launches-apple-news-plus-an-immersive-magazine-and-news-reading-experience/
# 	snippet: Cupertino, California — Apple today announced Apple News+ , a new subscription service that brings together over 300 popular magazines, leading ...
# 	content: Apple launches Apple News+, an immersive magazine and news reading experience - Apple PRESS RELEASE March 25, 2019 Apple launches Apple News+, an immersive magazine and news reading experience Subscribers to Enjoy Personalized, Comprehensive Access to Over 300 Publications Within Apple News Apple News+ subscribers gain access to over 300 publications that meet any interest. Cupertino, California — Apple today announced Apple News+ , a new subscription service that brings together over 300 popular magazines, leading newspapers and digital publishers into a beautiful, convenient and curated experience within the Apple News app. Available in the US and Canada, Apple News+ presents the best and most relevant articles to meet any range of interests from renowned publications such as Vogue, National Geographic Magazine, People, ELLE, The Wall Street Journal and Los Angeles Times. Apple News+ features richly designed layouts, animated covers, vivid photography and bold typography optimized for iPhone, iPad and Mac. Apple News+ adds an even more expansive collection of high-quality stories to the free experience of Apple News, which is the No. 1 news app and delivers current events coverage from trusted sources. 1 All Apple News users in the US, Canada, UK and Australia can continue to enjoy the free news experience within the app on iPhone, iPad and Mac, including access to Top Stories, Trending Stories and a personalized feed of articles. “We’re committed to supporting quality journalism, and with Apple News+, we want to celebrate the great work being done by magazines and news outlets,” said Lauren Kern, editor-in-chief of Apple News. “We think the breadth and quality of publications within Apple News+ will encourage more people to discover stories and titles they may never have come across before.” Apple News+ adds an even more expansive collection of high-quality stories to the free experience of Apple News. Apple News+ adds an even more expansive collection of high-qu
# --------------------------------------------------

# %% [markdown]
# #### 1b. Polygon API [5 points]
#
# The Polygon API provides real-time and historical financial data. We'll use this for analyzing stock market information.
#
# Key features:
# - Real-time stock quotes
# - Historical price data
# - Technical indicators
# - Company fundamentals
#
# Deliverable: In the ``cs329a_hw3/api_manager.py`` file, implement the ``get_stock_data`` function.

# %%
ticker, date = "TSLA", "2025-08-27"
stock_data = api_manager.get_stock_data(ticker=ticker, date=date)
if isinstance(stock_data, dict):
    print(f"\nStock data for {ticker} on {date}:")
    for k, v in stock_data.items():
        print(f"\t{k}: {v}")
else:
    print("\tNo stock data available")
# Out:
# Stock data for TSLA on 2025-08-27:
# 	ticker: TSLA
# 	date: 2025-08-27
# 	open: 351.94
# 	high: 355.39
# 	low: 349.156
# 	close: 349.6
# 	volume: 65519012.0

# %% [markdown]
# #### 1c. Wolfram Alpha API [5 points]
#
# The Wolfram Alpha API provides powerful computational capabilities to answer mathematical queries.
#
# **Deliverable**: In the ``cs329a_hw3/api_manager.py`` file, implement the `compute` function.

# %%
math_query = "integral cos(x)/sqrt(x) from 0 to 1"
result = api_manager.compute(math_query)
print(f"Wolfram Alpha result for {math_query}: {result}")
# Out:
# Wolfram Alpha result for integral cos(x)/sqrt(x) from 0 to 1: {'query': 'integral cos(x)/sqrt(x) from 0 to 1', 'result': 'integral_0^1 cos(x)/sqrt(x) dx = -1/2 (-1)^(3/4) sqrt(π) (erf((-1)^(1/4)) + erfi((-1)^(1/4)))≈1.80905', 'details': {'Definite integral': 'integral_0^1 cos(x)/sqrt(x) dx = -1/2 (-1)^(3/4) sqrt(π) (erf((-1)^(1/4)) + erfi((-1)^(1/4)))≈1.80905', 'Visual representation of the integral': None, 'Indefinite integral': 'integral cos(x)/sqrt(x) dx = -(i (sqrt(-i x) Γ(1/2, -i x) - sqrt(i x) Γ(1/2, i x)))/(2 sqrt(x)) + constant'}}

# %% [markdown]
# #### 1d. Weather API [5 points]
#
# The Weather API provides historical weather data for any location, including temperature, precipitation, wind, etc.
#
# To impement this, we'll use Nominatim from the [Geopy API](https://geopy.readthedocs.io/en/stable/) to geocode a location, and then use the [Open-Meteo API](https://open-meteo.com/) to get the weather data for that location.
#
# Deliverable: In the ``cs329a_hw3/api_manager.py`` file, implement the ``get_weather`` function.

# %%
# We can use the API manager's weather functionality
from datetime import datetime
location = "Palo Alto, CA"
date = datetime.now().strftime('%Y-%m-%d')
hour = "14"

weather_data = api_manager.get_weather(location, date, hour)
if "error" not in weather_data:
    print(f"Weather conditions for {location} on {date} at {hour}:00:")
    for k, v in weather_data.items():
        print(f"\t{k}: {v}")
else:
    print(f"\tCould not get weather data for {location}: {weather_data['error']}")
# Out:
# Weather conditions for Palo Alto, CA on 2026-06-21 at 14:00:
# 	location: Palo Alto, CA
# 	date: 2026-06-21
# 	hour: 14:00
# 	temperature: 77.9
# 	weather: Clear
# 	humidity: 44
# 	wind_speed: 5.9

# %% [markdown]
# #### 1e. API Routing [15 points]
#
# The API routing is a system that uses language models to route queries to the appropriate API function. This allows us to build an agent that can use multiple APIs to answer user queries.
#
# Key requirements for the function logic and prompt construction:
# - Query an LLM to determine the appropriate API to use for the query
# - Correctly parse the query response and map it to the appropriate API function
# - In the query response, include the API name and parameters to be used
# - Query the selected API and return the response from the API after parsing
# - Handle edge cases and fallbacks for query parsing and API selection
#
# Deliverable: In the ``cs329a_hw3/api_manager.py`` file, implement the ``_parse_query_params`` and ``route_query`` functions.
#
# Note: TogetherAI supports structured outputs, which can simplify the implementation of these functions: https://docs.together.ai/docs/json-mode.
# We use Pydantic models to define the expected parameters for each API.

# %%
from cs329a_hw3.evaluation import prepare_dataset

dataset = prepare_dataset(debug_mode=True)
queries, answers = dataset['query'], dataset['answer']
for query in queries:
    print(f"Query: {query}")
    output = api_manager.route_query(query, model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo")
    print(f"Called `{output['api_used']}` with parameters: {output['params']}")
    print("Result:", output["results"])
    print("API Used:", output["api_used"])
    print("-" * 50)
    break
# Out:
# Query: Were there any thunderstorms in Seattle, WA at noon on June 1st, 2025?
# Called `get_weather` with parameters: {'location': 'Seattle, WA', 'date': '2025-06-01', 'hour': '12'}
# Result: {'location': 'Seattle, WA', 'date': '2025-06-01', 'hour': '12:00', 'temperature': 60.0, 'weather': 'Mainly Clear', 'humidity': 56, 'wind_speed': 6.3}
# API Used: get_weather
# --------------------------------------------------

# %% [markdown]
# #### 1f. Evaluation with a single API call [5 points]
#
# With the API router complete, let's evaluate its performance. This involves routing a query to the correct API, getting the data, and then prompting an LLM with both the original query and the API data to generate a final answer.
#
# **Deliverable:**
# - In `cs329a_hw3/multi_lm_agent.py`, implement the `single_LM_with_single_API_call` function.`
#
# Key requirements for the function prompt and logic:
# - Query the API manager for the necessary data
# - Use the query and the data retrieved from the API manager to create a prompt for the model
# - Use the model to generate the response
# - Return the response from the model
#
# Deliverable: In the `cs329a_hw3/multi_lm_agent.py` file, implement the `single_LM_with_single_API_call` function.

# %%
from cs329a_hw3.evaluation import evaluate_qa, prepare_dataset

multi_lm_agent = MultiLMAgent(api_manager)
dataset = prepare_dataset(debug_mode=True)

queries, answers = dataset['query'], dataset['answer']
num_correct = 0

print("Single-Call LM with Single API Call:")
single_LM_with_single_API_call_responses = []
for query, answer in zip(queries, answers):
    response = multi_lm_agent.single_LM_with_single_API_call(query=query, model="meta-llama/Llama-3.3-70B-Instruct-Turbo-Free")
    single_LM_with_single_API_call_responses.append(response)
    print(f"Query: {query}")
    print(f"Single-Call LM Response: {response}")
    print(f"Answer: {answer}")
    is_correct = evaluate_qa(query, response, answer, model="google/gemma-3n-E4B-it")
    num_correct += is_correct
    print("Is Correct:", is_correct)
    print("-" * 50)

accuracy_singleLM_with_single_API_call = num_correct / len(queries)
print(f"Accuracy = {accuracy_singleLM_with_single_API_call*100:.1f}%")
# Out:
# Single-Call LM with Single API Call:
# Query: Were there any thunderstorms in Seattle, WA at noon on June 1st, 2025?
# Single-Call LM Response: No, there were no thunderstorms in Seattle, WA at noon on June 1st, 2025. According to the weather data, the conditions at that time were "Mainly Clear" with a temperature of 60°F, 56% humidity, and a wind speed of 6.3 mph.
# Answer: No
# Is Correct: True
# --------------------------------------------------
# Query: Which city was windier on August 1, 2025: Chicago or Boston?
# Single-Call LM Response: I'm unable to answer this question because the weather data for August 1, 2025 is not available. The API returned no results (null).
#
# August 1, 2025 is in the future, and weather forecasts are typically only reliable for about 10-14 days in advance. Historical weather data would only be available for dates that have already occurred.
#
# If you're interested in:
# - **Historical wind data** for a past August 1st (like August 1, 2024), I could help with that
# - **Current or near-future weather forecasts** for Chicago and Boston, I could assist with that instead
#
# Please let me know if you'd like to adjust your question!
# Answer: Boston
# Is Correct: False
# --------------------------------------------------
# Query: Did Tesla (TSLA) stock go up or down on March 5, 2025 compared to its opening price on that day?
# Single-Call LM Response: Based on the stock data for Tesla (TSLA) on March 5, 2025:
#
# **Tesla stock went UP on that day.**
#
# - **Opening price:** $272.92
# - **Closing price:** $279.10
# - **Change:** +$6.18 (approximately +2.26%)
#
# The stock closed at $279.10, which was higher than its opening price of $272.92, representing a gain for the day.
# Answer: up
# Is Correct: True
# --------------------------------------------------
# Query: From 4 Nov 2024 to 6 Nov 2024 inclusive (the two days around the U.S. election), what was the change in Tesla closing stock price, rounded to the nearest percent?
# Single-Call LM Response: # Tesla Stock Price Change (Nov 4-6, 2024)
#
# Based on the API result provided, I have the closing price for November 4, 2024:
# - **Nov 4, 2024 close: $242.84**
#
# However, the API result only includes data for November 4th and does not include the closing price for November 6th, 2024. Without the November 6th closing price, I cannot calculate the complete price change for the period you requested.
#
# To answer your question accurately, I would need the closing price for November 6, 2024. Could you provide that data, or would you like me to help with a different calculation?
# Answer: 19
# Is Correct: False
# --------------------------------------------------
# Query: A random variable X has probability density function proportional to cos(x)/sqrt(x) from 1 to 2. What is the normalization constant should this be multiplied by to make this a valid PDF? Round your answer to the nearest integer.
# Single-Call LM Response: # Solution
#
# To find the normalization constant, I need to determine what value $c$ makes this a valid PDF:
#
# $$\int_1^2 c \cdot \frac{\cos(x)}{\sqrt{x}} \, dx = 1$$
#
# From the API result, we have:
# $$\int_1^2 \frac{\cos(x)}{\sqrt{x}} \, dx \approx 0.0792006$$
#
# Therefore, the normalization constant is:
# $$c = \frac{1}{0.0792006} \approx 12.626$$
#
# Rounding to the nearest integer: **13**
# Answer: 13
# Is Correct: True
# --------------------------------------------------
# Query: Find the real solution to x^3 = x^5 + 100. Give your answer to the nearest hundredth.
# Single-Call LM Response: # Solution
#
# The equation x³ = x⁵ + 100 can be rearranged as:
# x³ - x⁵ - 100 = 0
#
# According to the computation result, the real solution is:
# **x ≈ -2.59**
#
# (rounded to the nearest hundredth)
# Answer: -2.59
# Is Correct: True
# --------------------------------------------------
# Query: What 2024 Beyoncé album broke streaming records with its blend of country-pop and Americana?
# Single-Call LM Response: # Answer
#
# **Cowboy Carter** is the 2024 Beyoncé album that broke streaming records with its blend of country-pop and Americana.
#
# Released on March 29, 2024, the album shattered multiple streaming records, including:
# - One of the most-streamed albums in a single day on Spotify in 2024
# - The biggest debut of the year for a country album on Spotify
# - The biggest debut ever for any album by a Black woman on Spotify, with over 76 million streams
# - Record-breaking performance on Amazon Music and other platforms
#
# The album is a genre-blending concept album rooted in country music, influenced by Beyoncé's Texas upbringing and spotlighting Black contributions to American musical and cultural history.
# Answer: Cowboy Carter
# Is Correct: True
# --------------------------------------------------
# Query: What is the title of the next Avatar film, scheduled for release on December 19, 2025?
# Single-Call LM Response: The title of the next Avatar film scheduled for release on December 19, 2025, is **Avatar: Fire and Ash**.
# Answer: Fire and Ash
# Is Correct: False
# --------------------------------------------------
# Accuracy = 62.5%

# %% [markdown]
# ## Part 2 - Self-improvement techniques [40 points]
# We now improve the accuracy by using a) **query decomposition and fusion** and b) **iterative self-refinement**

# %% [markdown]
# #### 2a. Query Decomposition [10 points]
#
# Complex queries often require information from multiple API calls (e.g., "Which city was windier, Chicago or Boston?"). To address such queries, we will first create the Query Decomposition component, which breaks down complex queries into simpler, more manageable parts, allowing us to use multiple APIs to answer the query.
#
# Key requirements:
# - Use the LLM to decompose the query into multiple independent sub-queries relevant for answering the original query (`_get_query_decomposition_prompt` and `_get_sub_queries` in `multi_lm_agent.py`)
# - Route each sub-query to the appropriate API using the API manager, and gather the structured API results and parameters from each sub-query
# - Error handling for failed decompositions, failed API calls, and failed query parsing
#
# Deliverable: In the `cs329a_hw3/multi_lm_agent.py` file, implement the `decompose_query`; as discussed above, this also requires implementing the `_get_query_decomposition_prompt` and `_get_sub_queries` helper functions.
#
# **Note**:
# - Using a `ThreadPoolExecutor` in your `decompose_query` implementation can significantly speed up execution by making multiple API calls concurrently.
# - Google Search webpage results can be very long, so they must be truncated or parsed to extract the relevant information and avoid exceeding the context window of the LMs.
# - The `decompose_query` method takes a query and returns a list of sub-queries. How do these sub-queries help with the overall task? What information do they provide that the original query does not?

# %%
from cs329a_hw3.multi_lm_agent import MultiLMAgent
from cs329a_hw3.evaluation import prepare_dataset, evaluate_qa

multi_lm_agent = MultiLMAgent(api_manager)

dataset = prepare_dataset(debug_mode=True)
queries, answers = dataset['query'], dataset['answer']

print("Testing Query Decomposition:")
decomposed_queries = []  # List[List[Dict]], where each inner list contains the decomposed queries for a single query
for query in queries:
    print(f"Original Query: {query}")
    decomposed_query = multi_lm_agent.decompose_query(query=query, max_sub_queries=3)

    print("Sub-queries:")
    for sub_query in decomposed_query:
        for k, v in sub_query.items():
            print(f"\t{k}: {v}")
        print()
    print("-" * 50)

    decomposed_queries.append(decomposed_query)
# Out:
# Testing Query Decomposition:
# Original Query: Were there any thunderstorms in Seattle, WA at noon on June 1st, 2025?
# Sub-queries:
# 	sub_query: What was the weather in Seattle, WA at noon on June 1st, 2025?
# 	api: get_weather
# 	params: {'location': 'Seattle, WA', 'date': '2025-06-01', 'hour': '12'}
# 	results: {'location': 'Seattle, WA', 'date': '2025-06-01', 'hour': '12:00', 'temperature': 60.0, 'weather': 'Mainly Clear', 'humidity': 56, 'wind_speed': 6.3}
# 	error: None
#
# --------------------------------------------------
# Original Query: Which city was windier on August 1, 2025: Chicago or Boston?
# Sub-queries:
# 	sub_query: What was the wind speed in Chicago on August 1, 2025?
# 	api: get_weather
# 	params: {'location': 'Chicago, USA', 'date': '2025-08-01', 'hour': '12'}
# 	results: {'location': 'Chicago, USA', 'date': '2025-08-01', 'hour': '12:00', 'temperature': 70.3, 'weather': 'Clear', 'humidity': 68, 'wind_speed': 8.3}
# 	error: None
#
# 	sub_query: What was the wind speed in Boston on August 1, 2025?
# 	api: get_weather
# 	params: {'location': 'Boston, USA', 'date': '2025-08-01', 'hour': '12'}
# 	results: {'location': 'Boston, USA', 'date': '2025-08-01', 'hour': '12:00', 'temperature': 69.1, 'weather': 'Mainly Clear', 'humidity': 67, 'wind_speed': 8.9}
# 	error: None
#
# --------------------------------------------------
# Original Query: Did Tesla (TSLA) stock go up or down on March 5, 2025 compared to its opening price on that day?
# Sub-queries:
# 	sub_query: What was Tesla (TSLA) stock open price, high price, low price, and close price on March 5, 2025?
# 	api: get_stock_data
# 	params: {'ticker': 'TSLA', 'date': '2025-03-05'}
# 	results: {'ticker': 'TSLA', 'date': '2025-03-05', 'open': 272.92, 'high': 279.55, 'low': 267.71, 'close': 279.1, 'volume': 94042913.0}
# 	error: None
#
# --------------------------------------------------
# Original Query: From 4 Nov 2024 to 6 Nov 2024 inclusive (the two days around the U.S. election), what was the change in Tesla closing stock price, rounded to the nearest percent?
# Sub-queries:
# 	sub_query: What was Tesla's closing stock price on November 4, 2024?
# 	api: get_stock_data
# 	params: {'ticker': 'TSLA', 'date': '2024-11-04'}
# 	results: {'ticker': 'TSLA', 'date': '2024-11-04', 'open': 244.56, 'high': 248.9, 'low': 238.88, 'close': 242.84, 'volume': 68802354.0}
# 	error: None
#
# 	sub_query: What was Tesla's closing stock price on November 6, 2024?
# 	api: get_stock_data
# 	params: {'ticker': 'TSLA', 'date': '2024-11-06'}
# 	results: {'ticker': 'TSLA', 'date': '2024-11-06', 'open': 284.67, 'high': 289.59, 'low': 275.62, 'close': 288.53, 'volume': 165228710.0}
# 	error: None
#
# 	sub_query: Calculate the percentage change from a starting value to an ending value, rounded to the nearest percent, where the starting value is the November 4 closing price and the ending value is the November 6 closing price.
# 	api: get_stock_data
# 	params: None
# 	results: None
# 	error: Failed to parse parameters.
#
# --------------------------------------------------
# Original Query: A random variable X has probability density function proportional to cos(x)/sqrt(x) from 1 to 2. What is the normalization constant should this be multiplied by to make this a valid PDF? Round your answer to the nearest integer.
# Sub-queries:
# 	sub_query: What is the integral of cos(x)/sqrt(x) from x=1 to x=2?
# 	api: compute
# 	params: {'wolfram_query': 'integrate cos(x)/sqrt(x) from 1 to 2'}
# 	results: {'query': 'integrate cos(x)/sqrt(x) from 1 to 2', 'result': 'integral_1^2 cos(x)/sqrt(x) dx = 1/2 (E_(1/2)(-i) + E_(1/2)(i) - sqrt(2) (E_(1/2)(-2 i) + E_(1/2)(2 i)))≈0.0792006', 'details': {'Definite integral': 'integral_1^2 cos(x)/sqrt(x) dx = 1/2 (E_(1/2)(-i) + E_(1/2)(i) - sqrt(2) (E_(1/2)(-2 i) + E_(1/2)(2 i)))≈0.0792006', 'Visual representation of the integral': None, 'Indefinite integral': 'integral cos(x)/sqrt(x) dx = -(i (sqrt(-i x) Γ(1/2, -i x) - sqrt(i x) Γ(1/2, i x)))/(2 sqrt(x)) + constant'}}
# 	error: None
#
# --------------------------------------------------
# Original Query: Find the real solution to x^3 = x^5 + 100. Give your answer to the nearest hundredth.
# Sub-queries:
# 	sub_query: Solve the equation x^3 = x^5 + 100 for real solutions and round to the nearest hundredth
# 	api: compute
# 	params: {'wolfram_query': 'solve x^3 = x^5 + 100 for real x'}
# 	results: {'query': 'solve x^3 = x^5 + 100 for real x', 'result': 'x≈-2.59403', 'details': {'Input interpretation': 'solve x^3 = x^5 + 100 for x over the reals', 'Result': 'x≈-2.59403', 'Plot': None, 'Number line': None}}
# 	error: None
#
# --------------------------------------------------
# Original Query: What 2024 Beyoncé album broke streaming records with its blend of country-pop and Americana?
# Sub-queries:
# 	sub_query: What 2024 Beyoncé album broke streaming records with country-pop and Americana blend?
# 	api: google_search
# 	params: {'search_query': '2024 Beyoncé album streaming records country-pop Americana', 'num_results': 2}
# 	results: [{'title': 'Cowboy Carter - Wikipedia', 'link': 'https://en.wikipedia.org/wiki/Cowboy_Carter', 'snippet': 'Cowboy Carter landed Beyoncé her biggest streaming week ever and broke streaming records on several platforms. [187][188] On Spotify, the album became one of the most-streamed albums in a single day in 2024, the biggest debut of the year for a country album, and the biggest debut ever for any album by a Black woman, with over 76 million ...', 'content': 'Cowboy Carter - Wikipedia Jump to content From Wikipedia, the free encyclopedia 2024 studio album by Beyoncé Cowboy Carter Standard cover Studio album by Beyoncé Released March 29, 2024 ( 2024-03-29 ) Recorded 2011 [ a ] [ 1 ] c. 2019–2024 [ 2 ] Studio APG Dezert Flower Electric Feel Kings Landing West Parkwood West Record Plant The Sound Factory The Village Westlake Recording (Los Angeles) The Cave East Iris The Library (Nashville) The Trailer ( East Hampton, New York ) Dolly P \'s Studio Genre Country country pop outlaw country pop Americana western country-soul blues hip-hop R&B Length 78 : 21 Language English Italian Label Parkwood Columbia Producer 070 Shake BAH Jon Batiste Beyoncé Cadenza Cam Miley Cyrus D.A. Got That Dope Derek Dixie Dixson Ian Fitchuk Harry Edwards Shawn Everett Nathan Ferraro Ink Tyler Johnson Paul McCartney No I.D. Nova Wav Dave Hamelin Killah B Nick Kobe Mamii Simon Mårtensson Pharrell Williams Jack Ro Raphael Saadiq Sean Solymar Sounwave Swizz Beatz The-Dream Khirye Tyler Beyoncé chronology Renaissance (2022) Cowboy Carter (2024) Singles from Cowboy Carter " Texas Hold \'Em " Released: February 11, 2024 " 16 Carriages " Released: February 11, 2024 " II Most Wanted " Released: April 15, 2024 Cowboy Carter (also referred to as Act II: Cowboy Carter ) is the eighth studio album by American singer and songwriter Beyoncé . It was released on March 29, 2024, by Parkwood Entertainment and Columbia Records . A concept album , Cowboy Carter is the second of a planned trilogy of albums, following Renaissance (2022). Beyoncé conceived the album as a journey through a reinvention of Americana , spotlighting the overlooked contributions of Black pioneers to American musical and cultural history . A genre-blending album rooted in country music , Cowboy Carter is influenced by Beyoncé\'s upbringing in Texas , incorporating eclectic styles of music of the Southern United States . Conceptually, the album is presented as a radio broadcast, with country singe'}, {'title': "Beyoncé's 'Cowboy Carter' Breaks Streaming Records On ... - Deadline", 'link': 'https://deadline.com/2024/03/beyonce-cowboy-carter-breaks-streaming-records-spotify-amazon-music-1235872718/', 'snippet': "Beyoncé's entry album into the country music genre, Cowboy Carter, was released on March 29, and it's already shattering records on streaming platforms.", 'content': "Beyoncé's 'Cowboy Carter' Breaks Streaming Records On Spotify & Amazon Music Continue to Deadline SKIP AD You will be redirected back to your article in seconds Skip to main content By Armando Tinoco Armando Tinoco Staff Writer @armietinoco More Stories By Armando ‘Supergirl’ First Reactions: “Mixed” Reviews, Praise Milly Alcock & Jason Momoa’s Roles & Highlight David Corenswet’s Superman As “Peak Casting” Rosie O’Donnell Is Open To Return To ‘The View’ As A Guest Host, “But They Haven’t Asked Me” Kyle Cooke Clarifies ‘Summer House’ “Isn’t Cancelled” & “This Is Not Me Announcing I Won’t Return” Following Emotional Message View All March 31, 2024 4:04pm 14 Comments Services to share this page. Share on Facebook Post Google Preferred Share to Flipboard Show more sharing options Email Share on LinkedIn Pin it Submit to Reddit Post to Tumblr Share on WhatsApp Print This Page Beyoncé Instagram @beyonce Beyoncé ‘s entry album into the country music genre, Cowboy Carter , was released on March 29, and it’s already shattering records on streaming platforms. After the “Texas Hold ‘Em” singer dropped her new album, Spotify said it ...
# 	error: None
#
# --------------------------------------------------
# Original Query: What is the title of the next Avatar film, scheduled for release on December 19, 2025?
# Sub-queries:
# 	sub_query: What is the title of the Avatar film scheduled for release on December 19, 2025?
# 	api: google_search
# 	params: {'search_query': 'Avatar film release December 19 2025', 'num_results': 5}
# 	results: [{'title': 'Avatar: Fire and Ash - Wikipedia', 'link': 'https://en.wikipedia.org/wiki/Avatar:_Fire_and_Ash', 'snippet': 'Avatar: Fire and Ash was released in the United States on December 19, 2025, by 20th Century Studios. [122][123][124] Like its predecessor, the film was subject to multiple delays (in this case, nine in total) since the crew took more time on the writing, pre-production and visual effects process.', 'content': 'Avatar: Fire and Ash - Wikipedia Jump to content From Wikipedia, the free encyclopedia "Avatar 3" and "Fire and Ash" redirect here. For the third season of Avatar: The Last Airbender , see Avatar: The Last Airbender season 3 . For other uses, see Fire and Ash (disambiguation) . 2025 film by James Cameron Avatar: Fire and Ash Theatrical release poster Directed by James Cameron Screenplay by James Cameron Rick Jaffa Amanda Silver Story by James Cameron Rick Jaffa Amanda Silver Josh Friedman Shane Salerno Produced by James Cameron Jon Landau Starring Sam Worthington Zoe Saldaña Sigourney Weaver Stephen Lang Kate Winslet Cinematography Russell Carpenter Edited by Stephen E. Rivkin [ a ] Nicolas de Toth John Refoua Jason Gaudio James Cameron David Brenner [ 1 ] Music by Simon Franglen [ b ] Production company Lightstorm Entertainment Distributed by 20th Century Studios Release dates December 1, 2025 ( 2025-12-01 ) ( Dolby Theatre ) [ 2 ] December 19, 2025 ( 2025-12-19 ) (United States) Running time 197 minutes [ 3 ] Country United States Language English Budget $350–400 million [ c ] Box office $1.490 billion [ 8 ] [ 9 ] Avatar: Fire and Ash is a 2025 American epic science fiction film directed by James Cameron from a screenplay he co-wrote with Rick Jaffa and Amanda Silver . Produced by Lightstorm Entertainment , it is the third installment in the Avatar film series and the sequel to Avatar: The Way of Water (2022). The film features Sam Worthington , Zoe Saldaña , Sigourney Weaver , Stephen Lang , and Kate Winslet reprising their roles from previous films. The story follows the human-turned- Na\'vi Jake Sully and his family on the habitable moon Pandora , as they face the combined threat of the human RDA forces and the Mangkwan, a ruthless Na\'vi clan. Following the box office success of Avatar (2009), Cameron announced two sequels, with Avatar 3 aiming for a December 2015 release. However, the addition of two further sequels and the development of new performance captur'}, {'title': 'Avatar: Fire and Ash (2025) - Movie | Moviefone', 'link': 'https://www.moviefone.com/movie/avatar-3/FWuSGLyAAvtzTcYFpQsOf6/main/', 'snippet': 'Watch on Amazon Video Avatar: Fire and Ash Highlights PG-13 3 hr 18 min Dec 19th, 2025 Adventure, Fantasy, Science Fiction Part of Avatar Collection Facebook X Reddit Embed Movie i Plot', 'content': 'Avatar: Fire and Ash (2025) - Movie | Moviefone Avatar: Fire and Ash (2025) "The world of Pandora will change forever." Movie Audience Score 76 Review Score 79 Starring Sam Worthington Zoe Saldaña Sigourney Weaver Director James Cameron Watch on Amazon Video Avatar: Fire and Ash Highlights PG-13 3 hr 18 min Dec 19th, 2025 Adventure , Fantasy , Science Fiction Part of Avatar Collection Facebook X Reddit Share Embed Movie Copied i Plot In the wake of the devastating war against the RDA and the loss of their eldest son, Jake Sully and Neytiri face a new threat on Pandora: the Ash People, a violent and power-hungry Na\'vi tribe led by the ruthless Varang. Jake\'s family must fight for their survival and the future of Pandora in a conflict that pushes them to their emotional and physical limits. Movie Details Where to Watch Videos Highlights Quotes Full Cast & Crew News Where to Watch Avatar: Fire and Ash powered by US UK CA AU TR FR DE IT NL IN BR UAE Amazon Video 4K Buy $19.99 Apple TV Store 4K Buy $19.99 Google Play Movies Buy $19.99 YouTube Buy $19.99 Avatar: Fire and Ash Review \'Avatar: Fire and Ash\' is a Visually Stunning One-Time Theatrical Experience. Breathtaking visuals  ...
# 	error: None
#
# --------------------------------------------------

# %% [markdown]
# #### 2b. Synthesizing information from sub-query API responses [5 points]
#
# After executing the sub-queries, we need to assemble a new, context-rich prompt that incorporates each sub-query's API response and the user's query. This will be given to a model to synthesize a final answer.
#
# Deliverable: In the `cs329a_hw3/multi_lm_agent.py` file, implement `_get_synthesis_prompt`.
#
# **Note**:
# - Do the prompts constructed provide all the necessary information to answer the query?
# - A good synthesis prompt should clearly present the original query and  neatly format the results from each successful API call

# %%
dataset = prepare_dataset(debug_mode=True)

queries, answers = dataset['query'], dataset['answer']
generated_prompts = []
for query, decomposed_query in zip(queries, decomposed_queries):
    generated_prompt = multi_lm_agent._get_synthesis_prompt(query, decomposed_query)
    print("Generated Prompt:")
    print(generated_prompt)
    print("-" * 50)
    generated_prompts.append(generated_prompt)
# Out:
# Generated Prompt:
# You are a helpful assistant. Using ONLY the tool results below, answer the user's question directly and concisely. Perform any final reasoning or arithmetic yourself (e.g. percent changes, comparisons). If the results are insufficient, give your best answer.
#
# User question: Were there any thunderstorms in Seattle, WA at noon on June 1st, 2025?
#
# Tool results:
# Sub-question 1: What was the weather in Seattle, WA at noon on June 1st, 2025?
# Tool: get_weather
# Result: {"location": "Seattle, WA", "date": "2025-06-01", "hour": "12:00", "temperature": 60.0, "weather": "Mainly Clear", "humidity": 56, "wind_speed": 6.3}
#
# Final answer:
# --------------------------------------------------
# Generated Prompt:
# You are a helpful assistant. Using ONLY the tool results below, answer the user's question directly and concisely. Perform any final reasoning or arithmetic yourself (e.g. percent changes, comparisons). If the results are insufficient, give your best answer.
#
# User question: Which city was windier on August 1, 2025: Chicago or Boston?
#
# Tool results:
# Sub-question 1: What was the wind speed in Chicago on August 1, 2025?
# Tool: get_weather
# Result: {"location": "Chicago, USA", "date": "2025-08-01", "hour": "12:00", "temperature": 70.3, "weather": "Clear", "humidity": 68, "wind_speed": 8.3}
#
# Sub-question 2: What was the wind speed in Boston on August 1, 2025?
# Tool: get_weather
# Result: {"location": "Boston, USA", "date": "2025-08-01", "hour": "12:00", "temperature": 69.1, "weather": "Mainly Clear", "humidity": 67, "wind_speed": 8.9}
#
# Final answer:
# --------------------------------------------------
# Generated Prompt:
# You are a helpful assistant. Using ONLY the tool results below, answer the user's question directly and concisely. Perform any final reasoning or arithmetic yourself (e.g. percent changes, comparisons). If the results are insufficient, give your best answer.
#
# User question: Did Tesla (TSLA) stock go up or down on March 5, 2025 compared to its opening price on that day?
#
# Tool results:
# Sub-question 1: What was Tesla (TSLA) stock open price, high price, low price, and close price on March 5, 2025?
# Tool: get_stock_data
# Result: {"ticker": "TSLA", "date": "2025-03-05", "open": 272.92, "high": 279.55, "low": 267.71, "close": 279.1, "volume": 94042913.0}
#
# Final answer:
# --------------------------------------------------
# Generated Prompt:
# You are a helpful assistant. Using ONLY the tool results below, answer the user's question directly and concisely. Perform any final reasoning or arithmetic yourself (e.g. percent changes, comparisons). If the results are insufficient, give your best answer.
#
# User question: From 4 Nov 2024 to 6 Nov 2024 inclusive (the two days around the U.S. election), what was the change in Tesla closing stock price, rounded to the nearest percent?
#
# Tool results:
# Sub-question 1: What was Tesla's closing stock price on November 4, 2024?
# Tool: get_stock_data
# Result: {"ticker": "TSLA", "date": "2024-11-04", "open": 244.56, "high": 248.9, "low": 238.88, "close": 242.84, "volume": 68802354.0}
#
# Sub-question 2: What was Tesla's closing stock price on November 6, 2024?
# Tool: get_stock_data
# Result: {"ticker": "TSLA", "date": "2024-11-06", "open": 284.67, "high": 289.59, "low": 275.62, "close": 288.53, "volume": 165228710.0}
#
# Sub-question 3: Calculate the percentage change from a starting value to an ending value, rounded to the nearest percent, where the starting value is the November 4 closing price and the ending value is the November 6 closing price.
# Tool: get_stock_data
# Result: null
#
# Final answer:
# --------------------------------------------------
# Generated Prompt:
# You are a helpful assistant. Using ONLY the tool results below, answer the user's question directly and concisely. Perform any final reasoning or arithmetic yourself (e.g. percent changes, comparisons). If the results are insufficient, give your best answer.
#
# User question: A random variable X has probability density function proportional to cos(x)/sqrt(x) from 1 to 2. What is the normalization constant should this be multiplied by to make this a valid PDF? Round your answer to the nearest integer.
#
# Tool results:
# Sub-question 1: What is the integral of cos(x)/sqrt(x) from x=1 to x=2?
# Tool: compute
# Result: {"query": "integrate cos(x)/sqrt(x) from 1 to 2", "result": "integral_1^2 cos(x)/sqrt(x) dx = 1/2 (E_(1/2)(-i) + E_(1/2)(i) - sqrt(2) (E_(1/2)(-2 i) + E_(1/2)(2 i)))\u22480.0792006", "details": {"Definite integral": "integral_1^2 cos(x)/sqrt(x) dx = 1/2 (E_(1/2)(-i) + E_(1/2)(i) - sqrt(2) (E_(1/2)(-2 i) + E_(1/2)(2 i)))\u22480.0792006", "Visual representation of the integral": null, "Indefinite integral": "integral cos(x)/sqrt(x) dx = -(i (sqrt(-i x) \u0393(1/2, -i x) - sqrt(i x) \u0393(1/2, i x)))/(2 sqrt(x)) + constant"}}
#
# Final answer:
# --------------------------------------------------
# Generated Prompt:
# You are a helpful assistant. Using ONLY the tool results below, answer the user's question directly and concisely. Perform any final reasoning or arithmetic yourself (e.g. percent changes, comparisons). If the results are insufficient, give your best answer.
#
# User question: Find the real solution to x^3 = x^5 + 100. Give your answer to the nearest hundredth.
#
# Tool results:
# Sub-question 1: Solve the equation x^3 = x^5 + 100 for real solutions and round to the nearest hundredth
# Tool: compute
# Result: {"query": "solve x^3 = x^5 + 100 for real x", "result": "x\u2248-2.59403", "details": {"Input interpretation": "solve x^3 = x^5 + 100 for x over the reals", "Result": "x\u2248-2.59403", "Plot": null, "Number line": null}}
#
# Final answer:
# --------------------------------------------------
# Generated Prompt:
# You are a helpful assistant. Using ONLY the tool results below, answer the user's question directly and concisely. Perform any final reasoning or arithmetic yourself (e.g. percent changes, comparisons). If the results are insufficient, give your best answer.
#
# User question: What 2024 Beyoncé album broke streaming records with its blend of country-pop and Americana?
#
# Tool results:
# Sub-question 1: What 2024 Beyoncé album broke streaming records with country-pop and Americana blend?
# Tool: google_search
# Result: [{"title": "Cowboy Carter - Wikipedia", "link": "https://en.wikipedia.org/wiki/Cowboy_Carter", "snippet": "Cowboy Carter landed Beyonc\u00e9 her biggest streaming week ever and broke streaming records on several platforms. [187][188] On Spotify, the album became one of the most-streamed albums in a single day in 2024, the biggest debut of the year for a country album, and the biggest debut ever for any album by a Black woman, with over 76 million ...", "content": "Cowboy Carter - Wikipedia Jump to content From Wikipedia, the free encyclopedia 2024 studio album by Beyonc\u00e9 Cowboy Carter Standard cover Studio album by Beyonc\u00e9 Released March 29, 2024 ( 2024-03-29 ) Recorded 2011 [ a ] [ 1 ] c. 2019\u20132024 [ 2 ] Studio APG Dezert Flower Electric Feel Kings Landing West Parkwood West Record Plant The Sound Factory The Village Westlake Recording (Los Angeles) The Cave East Iris The Library (Nashville) The Trailer ( East Hampton, New York ) Dolly P 's Studio Genre Country country pop outlaw country pop Americana western country-soul blues hip-hop R&B Length 78 : 21 Language English Italian Label Parkwood Columbia Producer 070 Shake BAH Jon Batiste Beyonc\u00e9 Cadenza Cam Miley Cyrus D.A. Got That Dope Derek Dixie Dixson Ian Fitchuk Harry Edwards Shawn Everett Nathan Ferraro Ink Tyler Johnson Paul McCartney No I.D. Nova Wav Dave Hamelin Killah B Nick Kobe Mamii Simon M\u00e5rtensson Pharrell Williams Jack Ro Raphael Saadiq Sean Solymar Sounwave Swizz Beatz The-Dream Khir
#
# Final answer:
# --------------------------------------------------
# Generated Prompt:
# You are a helpful assistant. Using ONLY the tool results below, answer the user's question directly and concisely. Perform any final reasoning or arithmetic yourself (e.g. percent changes, comparisons). If the results are insufficient, give your best answer.
#
# User question: What is the title of the next Avatar film, scheduled for release on December 19, 2025?
#
# Tool results:
# Sub-question 1: What is the title of the Avatar film scheduled for release on December 19, 2025?
# Tool: google_search
# Result: [{"title": "Avatar: Fire and Ash - Wikipedia", "link": "https://en.wikipedia.org/wiki/Avatar:_Fire_and_Ash", "snippet": "Avatar: Fire and Ash was released in the United States on December 19, 2025, by 20th Century Studios. [122][123][124] Like its predecessor, the film was subject to multiple delays (in this case, nine in total) since the crew took more time on the writing, pre-production and visual effects process.", "content": "Avatar: Fire and Ash - Wikipedia Jump to content From Wikipedia, the free encyclopedia \"Avatar 3\" and \"Fire and Ash\" redirect here. For the third season of Avatar: The Last Airbender , see Avatar: The Last Airbender season 3 . For other uses, see Fire and Ash (disambiguation) . 2025 film by James Cameron Avatar: Fire and Ash Theatrical release poster Directed by James Cameron Screenplay by James Cameron Rick Jaffa Amanda Silver Story by James Cameron Rick Jaffa Amanda Silver Josh Friedman Shane Salerno Produced by James Cameron Jon Landau Starring Sam Worthington Zoe Salda\u00f1a Sigourney Weaver Stephen Lang Kate Winslet Cinematography Russell Carpenter Edited by Stephen E. Rivkin [ a ] Nicolas de Toth John Refoua Jason Gaudio James Cameron David Brenner [ 1 ] Music by Simon Franglen [ b ] Production company Lightstorm Entertainment Distributed by 20th Century Studios Release dates December 1, 2025 ( 2025-12-01 ) ( Dolby Theatre ) [ 2 ] December 19, 2025 ( 2025-12-19 ) (United States) Running time 197 minutes [ 3 ] Country United States Language
#
# Final answer:
# --------------------------------------------------

# %% [markdown]
# #### 2c. Fusion of responses [5 points]
#
# With the constructed prompt, we can generate multiple responses with different models to get a diverse set of responses, and then use a fusion model to combine the best elements from each into a single coherent output. This generally provides a more robust, comprehensive response than any single model could provide.
#
# Key requirements for prompt construction:
# - Call `decompose_query` and `_get_synthesis_prompt` to get the decomposed queries and the generated synthesis prompt (which contains the original query and the results from each sub-query)
# - Query multiple models with the generated synthesis prompt (specifically `"google/gemma-3n-E4B-it"`, `"meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo"`, and `"OpenAI/gpt-oss-20B"`)
# - Combine elements from these multiple responses by creating a new fusion prompt, while maintaining consistency and clarity in the final response
# - Handle edge cases and fallbacks
# - Return the final response from the fusion model
#
# Deliverable: In the `cs329_hw3/multi_lm_agent.py` file, implement the `decompose_and_fuse`.This function orchestrates the full query decomposition and fusion workflow. It should make internal calls to `decompose_query`, `_get_synthesis_prompt`, and `generate`. For the fusion step, you should sample from in parallel, then feed their responses to the final fusion model.
#
# **Note**: The `fuse` method should take the generated prompt and multiple generated responses before returning a single fused response. Compare how the fused response is different from the individual responses.

# %%
from cs329a_hw3.evaluation import evaluate_qa, prepare_dataset

dataset = prepare_dataset(debug_mode=True)
queries, answers = dataset['query'], dataset['answer']

print("Generated Responses with Query Decomposition + Fusion:")
query_decomp_responses = []
num_correct = 0
for query, answer in zip(queries, answers):
    response = multi_lm_agent.decompose_and_fuse(query)
    query_decomp_responses.append(response)
    print(f"Query: {query}")
    print(f"Query Decomposition + Fusion Response: {response}")
    print(f"Answer: {answer}")
    is_correct = evaluate_qa(query, response, answer, model="google/gemma-3n-E4B-it")
    num_correct += is_correct
    print("Is Correct:", is_correct)
    print("-" * 50)

accuracy_query_decomp = num_correct / len(queries)
print(f"Accuracy = {accuracy_query_decomp*100:.1f}%")
# Out:
# Generated Responses with Query Decomposition + Fusion:
# Query: Were there any thunderstorms in Seattle, WA at noon on June 1st, 2025?
# Query Decomposition + Fusion Response: # Final Answer
#
# No, there were no thunderstorms in Seattle, WA at noon on June 1st, 2025. The weather conditions at that time were mainly clear, with a temperature of 60°F, 56% humidity, and wind speeds of 6.3 mph.
# Answer: No
# Is Correct: True
# --------------------------------------------------
# Query: Which city was windier on August 1, 2025: Chicago or Boston?
# Query Decomposition + Fusion Response: **Boston was windier on August 1, 2025.**
#
# Boston had a wind speed of 8.9 mph compared to Chicago's 8.3 mph, a difference of 0.6 mph.
# Answer: Boston
# 03:00:32 - LiteLLM:WARNING: vertex_and_google_ai_studio_gemini.py:1191 - DeprecationWarning: `temperature`, `top_p`, and `top_k` continue to function for Gemini 3+ (gemini-3.1-flash-lite) but are planned for removal in a future release. Move sampling guidance into the `system` instructions instead.
# Is Correct: True
# --------------------------------------------------
# Query: Did Tesla (TSLA) stock go up or down on March 5, 2025 compared to its opening price on that day?
# Query Decomposition + Fusion Response: # Final Answer
#
# **Tesla (TSLA) stock went UP on March 5, 2025.**
#
# - **Opening price:** $272.92
# - **Closing price:** $279.10
# - **Change:** +$6.18 (+2.26%)
#
# All three candidate answers agree on this conclusion with consistent data points. The stock closed higher than its opening price on that day.
# Answer: up
# 03:00:35 - LiteLLM:WARNING: vertex_and_google_ai_studio_gemini.py:1191 - DeprecationWarning: `temperature`, `top_p`, and `top_k` continue to function for Gemini 3+ (gemini-3.1-flash-lite) but are planned for removal in a future release. Move sampling guidance into the `system` instructions instead.
# Is Correct: True
# --------------------------------------------------
# Query: From 4 Nov 2024 to 6 Nov 2024 inclusive (the two days around the U.S. election), what was the change in Tesla closing stock price, rounded to the nearest percent?
# Query Decomposition + Fusion Response: # Final Answer
#
# **+19%**
#
# All three candidates agree on this answer, and the calculation is correct:
#
# - **November 4, 2024 closing price:** $242.84
# - **November 6, 2024 closing price:** $288.53
# - **Percentage change:** ($288.53 - $242.84) / $242.84 × 100 = 18.82% ≈ **+19%** (rounded to nearest percent)
#
# Tesla's stock price increased by 19% over the two-day period around the 2024 U.S. election.
# Answer: 19
# 03:00:39 - LiteLLM:WARNING: vertex_and_google_ai_studio_gemini.py:1191 - DeprecationWarning: `temperature`, `top_p`, and `top_k` continue to function for Gemini 3+ (gemini-3.1-flash-lite) but are planned for removal in a future release. Move sampling guidance into the `system` instructions instead.
# Is Correct: True
# --------------------------------------------------
# Query: A random variable X has probability density function proportional to cos(x)/sqrt(x) from 1 to 2. What is the normalization constant should this be multiplied by to make this a valid PDF? Round your answer to the nearest integer.
# Query Decomposition + Fusion Response: # Final Answer
#
# **13**
#
# ## Justification
#
# All three candidates arrive at the same correct answer through the proper methodology:
#
# 1. **Correct approach**: For a function to be a valid PDF, it must integrate to 1 over its domain. The normalization constant C is found by:
#    $$C = \frac{1}{\int_1^2 \frac{\cos(x)}{\sqrt{x}} dx}$$
#
# 2. **Integral evaluation**: The integral ∫₁² cos(x)/√x dx ≈ 0.0792006
#
# 3. **Calculation**: C = 1/0.0792006 ≈ 12.626
#
# 4. **Rounding**: 12.626 rounds to **13**
#
# All three responses correctly identify the method, compute the integral accurately, and arrive at the same rounded answer. The answer is mathematically sound and well-justified.
# Answer: 13
# 03:00:44 - LiteLLM:WARNING: vertex_and_google_ai_studio_gemini.py:1191 - DeprecationWarning: `temperature`, `top_p`, and `top_k` continue to function for Gemini 3+ (gemini-3.1-flash-lite) but are planned for removal in a future release. Move sampling guidance into the `system` instructions instead.
# Is Correct: True
# --------------------------------------------------
# Query: Find the real solution to x^3 = x^5 + 100. Give your answer to the nearest hundredth.
# Query Decomposition + Fusion Response: # Solution to x³ = x⁵ + 100
#
# Let me verify this answer by rearranging the equation:
# $$x^3 = x^5 + 100$$
# $$x^3 - x^5 - 100 = 0$$
# $$-x^5 + x^3 - 100 = 0$$
#
# Let me check x ≈ -2.59:
# - $(-2.59)^3 = -17.373...$
# - $(-2.59)^5 = -114.415...$
# - $(-2.59)^3 - (-2.59)^5 - 100 = -17.373 + 114.415 - 100 ≈ -2.96$ (close to 0)
#
# Let me refine: Testing x ≈ -2.5945:
# - $(-2.5945)^3 ≈ -17.476$
# - $(-2.5945)^5 ≈ -114.476$
# - Sum: $-17.476 + 114.476 - 100 ≈ 0$ ✓
#
# **Final Answer: x ≈ -2.59**
#
# All three candidates agree on this answer, which checks out numerically.
# Answer: -2.59
# 03:00:48 - LiteLLM:WARNING: vertex_and_google_ai_studio_gemini.py:1191 - DeprecationWarning: `temperature`, `top_p`, and `top_k` continue to function for Gemini 3+ (gemini-3.1-flash-lite) but are planned for removal in a future release. Move sampling guidance into the `system` instructions instead.
# Is Correct: True
# --------------------------------------------------
# Query: What 2024 Beyoncé album broke streaming records with its blend of country-pop and Americana?
# Query Decomposition + Fusion Response: # Final Answer
#
# **Cowboy Carter**
#
# This 2024 Beyoncé album, released on March 29, 2024, broke multiple streaming records with its country-pop and Americana blend, including the biggest debut ever for an album by a Black woman with over 76 million streams on its opening day.
# Answer: Cowboy Carter
# 03:00:52 - LiteLLM:WARNING: vertex_and_google_ai_studio_gemini.py:1191 - DeprecationWarning: `temperature`, `top_p`, and `top_k` continue to function for Gemini 3+ (gemini-3.1-flash-lite) but are planned for removal in a future release. Move sampling guidance into the `system` instructions instead.
# Is Correct: True
# --------------------------------------------------
# Query: What is the title of the next Avatar film, scheduled for release on December 19, 2025?
# Query Decomposition + Fusion Response: # Final Answer
#
# **Avatar: Fire and Ash**
#
# All three candidates agree on this title, which is the correct answer for the Avatar film scheduled for December 19, 2025.
# Answer: Fire and Ash
# Is Correct: False
# --------------------------------------------------
# Accuracy = 87.5%

# %% [markdown]
# #### 2d. Iterative Self-Refinement [20 points]
#
# Sometimes a single round of decomposition is not enough to answer the query. To address this, Iterative Refinement improves the response by querying for more information as needed across multiple APIs.
#
# At each step, the agent can either issue a new sub-query to gather more information (e.g. if a prior sub-query failed or if additional information is needed); or generate the final answer if it has enough information. This can be particularly useful for complex queries that require multiple API calls to answer, such as multi-hop question-answering where the result of one step informs the next.
#
# Deliverable: In `cs329a_hw3/multi_lm_agent.py`, implement the `iterative_refine` method.
#
# Key requirements for function logic and prompt construction:
# - At each step, you should construct a prompt with the user query, cleanly formatted API results of all previous sub-queries, and instructions for the LLM to either issue a new sub-query or generate the final answer (`_get_iterative_refinement_prompt` of `cs329a_hw3/multi_lm_agent.py`)
# - Based on the LLM's response, you should either get an API response for a new sub-query (using the `route_query` method) or return its response as the final answer.
# - Exit when the model outputs a final answer, or when the maximum number of iterations is reached.
#
# Note unlike query decomposition + fusion, the iterative refinement module allows for sub-queries to be re-issued if an earlier sub-query failed, as well as for intermediate information to be incorporated into subsequent sub-queries.
#
# For resources on LM judges and self-verification, see:
# - [LM Judge Survey](https://arxiv.org/abs/2411.15594)
# - [Large Language Models are Better Reasoners with Self-Verification](https://arxiv.org/abs/2212.09561)

# %%
from cs329a_hw3.evaluation import evaluate_qa, prepare_dataset
from tqdm import tqdm

dataset = prepare_dataset(debug_mode=True)
queries, answers = dataset['query'], dataset['answer']

multi_lm_agent = MultiLMAgent(api_manager)
print("Generated Responses with Iterative Refinement:")
iterative_refine_responses = []
num_correct = 0
for query, answer in tqdm(zip(queries, answers)):
    print(f"Query: {query}")
    
    response = multi_lm_agent.iterative_refine(query, max_iterations=4)
    print(f"Iterative Refinement Response: {response}")
    iterative_refine_responses.append(response)
    
    print(f"Answer: {answer}")
    is_correct = evaluate_qa(query, response, answer, model="google/gemma-3n-E4B-it")
    num_correct += is_correct
    print("Is Correct:", is_correct)
    print("-" * 50)
    
accuracy_iterative_refine = num_correct / len(queries)
print(f"Accuracy = {accuracy_iterative_refine*100:.1f}%")
# Out:
# Generated Responses with Iterative Refinement:
# Query: Were there any thunderstorms in Seattle, WA at noon on June 1st, 2025?
# Iterative Refinement Response: No, there were no thunderstorms in Seattle, WA at noon on June 1st, 2025. According to the weather data, the conditions at that time were "Mainly Clear" with a temperature of 60°F, 56% humidity, and wind speed of 6.3 mph.
# Answer: No
# Is Correct: True
# --------------------------------------------------
# Query: Which city was windier on August 1, 2025: Chicago or Boston?
# Iterative Refinement Response: Boston was windier on August 1, 2025. Boston had a wind speed of 8.9 mph compared to Chicago's 8.3 mph at noon on that date.
# Answer: Boston
# Is Correct: True
# --------------------------------------------------
# Query: Did Tesla (TSLA) stock go up or down on March 5, 2025 compared to its opening price on that day?
# Iterative Refinement Response: Tesla (TSLA) stock went UP on March 5, 2025. The opening price was $272.92 and the closing price was $279.10, representing an increase of $6.18 or approximately 2.26% for the day.
# Answer: up
# Is Correct: True
# --------------------------------------------------
# Query: From 4 Nov 2024 to 6 Nov 2024 inclusive (the two days around the U.S. election), what was the change in Tesla closing stock price, rounded to the nearest percent?
# Iterative Refinement Response: From November 4, 2024 to November 6, 2024, Tesla's closing stock price changed from $242.84 to $288.53, representing an increase of 18.81%, which rounds to **19%**.
# Answer: 19
# Is Correct: True
# --------------------------------------------------
# Query: A random variable X has probability density function proportional to cos(x)/sqrt(x) from 1 to 2. What is the normalization constant should this be multiplied by to make this a valid PDF? Round your answer to the nearest integer.
# Iterative Refinement Response: The normalization constant is the reciprocal of the integral. Since the integral of cos(x)/√x from 1 to 2 equals approximately 0.0792006, the normalization constant is:
#
# 1 / 0.0792006 ≈ 12.63
#
# Rounded to the nearest integer: **13**
# Answer: 13
# Is Correct: True
# --------------------------------------------------
# Query: Find the real solution to x^3 = x^5 + 100. Give your answer to the nearest hundredth.
# Iterative Refinement Response: The real solution to x^3 = x^5 + 100 is **x ≈ -2.59** (rounded to the nearest hundredth).
# Answer: -2.59
# Is Correct: True
# --------------------------------------------------
# Query: What 2024 Beyoncé album broke streaming records with its blend of country-pop and Americana?
# Iterative Refinement Response: Cowboy Carter is the 2024 Beyoncé album that broke streaming records with its blend of country-pop and Americana. Released on March 29, 2024, it became Beyoncé's biggest streaming week ever, achieving over 76 million streams on Spotify in its debut, making it the biggest debut of the year for a country album and the biggest debut ever for any album by a Black woman.
# Answer: Cowboy Carter
# Is Correct: True
# --------------------------------------------------
# Query: What is the title of the next Avatar film, scheduled for release on December 19, 2025?
# Iterative Refinement Response: The title of the next Avatar film scheduled for release on December 19, 2025, is "Avatar: Fire and Ash". It is directed by James Cameron and was released by 20th Century Studios.
# Answer: Fire and Ash
# Is Correct: True
# --------------------------------------------------
# Accuracy = 100.0%

# %% [markdown]
# Create a bar graph plotting the accuracies of zero-shot prompting, a single API router and LM call, query decomposition and fusion, and iterative refinement (max 4 rounds).

# %%
from matplotlib import pyplot as plt

# Create data for the bar graph
methods = ['Zero-shot', 'Single API router and LM call', 'Query decomposition and fusion', 'Iterative refinement']

# Must be in this order and in floating point format from 0.0 to 1.0
accuracies = [
    accuracy_zero_shot,
    accuracy_singleLM_with_single_API_call, 
    accuracy_query_decomp,
    accuracy_iterative_refine
]

colors = ['#FF9999', '#66B2FF', '#99FF99', '#FFCC99']

plt.figure(figsize=(10, 6))
bars = plt.bar(methods, accuracies, color=colors)

plt.title('Accuracy Comparison Across Different LLM Pipelines')
plt.ylabel('Accuracy')
plt.ylim(0, 1.0)

plt.xticks(rotation=45, ha='right')
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height, f'{height:.2%}', ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 3 - Building an LLM Agentic Workflow [15 points]
#
# Using the components we've built (or new ones you've implemented), build an LLM agent that can answer the following questions about the world. These questions will be a mix of the types of questions we've built components for and will require using the APIs in creative ways.
#
# Some questions will require just a single API call, while others will require multiple API calls and multiple rounds of iterative refinement. Create a pipeline that can dynamically adjust to the complexity of the question. Feel free to implement new components or use the ones we've already built!
#
# If you get above 70% accuracy on the entire dataset, you will get full points. For scores below 70%, you will get partial credit based on the percentage of accuracy.
#
# **Important**: Make sure to evaluate over the entire dataset when you are confident with your implementation! This will help you preserve inference compute credits and speed up the development process. Please use "meta-llama/Llama-3.3-70B-Instruct-Turbo-Free" for the iterative refinement and decomposition models, and "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo" for the fusion model.
#
# Deliverable: In the `cs329a_hw3/multi_lm_agent.py` file, implement the `run_pipeline` method, which takes a query and returns a final response.
#
# **Note**: How does the performance on the dataset compare between single-call LMs vs. the complete pipeline with the multi-LM agent? How does it improve accuracy by improving access to tool APIs and allowing for more complex reasoning?

# %% [markdown]
# Let's first evaluate over the entire dataset with just a zero-shot model
# - **IMPORTANT**: Make sure to evaluate over the entire dataset only when you are confident with your implementation!
# - This will help you preserve inference compute credits and speed up the development process.

# %%
# Let's first evaluate the zero-shot performance over the entire dataset
# IMPORTANT: Make sure to evaluate over the entire dataset when you are confident with your implementation! 
# This will help you preserve inference compute credits and speed up the development process.

from cs329a_hw3.evaluation import evaluate_qa, prepare_dataset

debug_mode = False # Loads the entire dataset for evaluation.
dataset = prepare_dataset(debug_mode=debug_mode)
queries, answers = dataset['query'], dataset['answer']

zero_shot_responses, num_correct = [], 0
for query, answer in zip(queries, answers):
    print(f"Query: {query}")
    response = multi_lm_agent.generate(query, model="meta-llama/Llama-3.3-70B-Instruct-Turbo-Free")
    zero_shot_responses.append(response)
    print(f"Zero-Shot Response: {response}")
    print(f"Answer: {answer}")
    is_correct = evaluate_qa(query, response, answer, model="google/gemma-3n-E4B-it")
    num_correct += is_correct
    print("Is Correct:", is_correct)
    print("-" * 50)

print("Evaluating full zero-shot performance...")
complete_set_zero_shot_accuracy = num_correct / len(queries)
print(f"Accuracy = {complete_set_zero_shot_accuracy*100:.1f}%")
# Out:
# Query: Were there any thunderstorms in Seattle, WA at noon on June 1st, 2025?
# Zero-Shot Response: I don't have access to real-time weather data or historical weather records for future dates. June 1st, 2025 is in the future, so I cannot tell you whether there were thunderstorms in Seattle at that time.
#
# If you're looking for weather information, I'd recommend:
# - **Weather.com** or **Weather.gov** for current/forecast conditions
# - **NOAA** for historical weather data (for past dates)
# - Local Seattle news sources for regional weather reports
#
# Is there something else I can help you with?
# Answer: No
# Is Correct: False
# --------------------------------------------------
# Query: Which city was windier on August 1, 2025: Chicago or Boston?
# Zero-Shot Response: I don't have access to real-time weather data or historical weather records for August 1, 2025. Since that date is in the future from my knowledge cutoff in April 2024, I cannot tell you which city was windier on that specific date.
#
# To find this information, you could check:
# - Weather history websites (like Weather Underground or NOAA)
# - Local weather archives for Chicago and Boston
# - Historical weather databases
#
# If you're asking about a past date or need current weather information, please let me know and I can try to help differently.
# Answer: Boston
# Is Correct: False
# --------------------------------------------------
# Query: Over the first three days of August 2025, did the morning (9AM) temperature in Miami ever drop below 70 Fahrenheit?
# Zero-Shot Response: I don't have access to real-time weather data or historical weather records for August 2025. Since August 2025 is in the future from my knowledge cutoff date (April 2024), I cannot provide information about actual temperatures that occurred during those dates.
#
# To find this information, you could check:
# - Weather history websites like Weather Underground or NOAA
# - Local Miami weather services
# - Weather archives that maintain historical records
#
# If you're asking this question after August 2025 has already passed, those sources would have the actual recorded data.
# Answer: No
# Is Correct: False
# --------------------------------------------------
# Query: Did Tesla (TSLA) stock go up or down on March 5, 2025 compared to its opening price on that day?
# Zero-Shot Response: I don't have access to real-time or future stock market data. My knowledge was last updated in April 2024, so I cannot provide information about Tesla's stock performance on March 5, 2025.
#
# To find this information, you can check:
# - Financial websites like Yahoo Finance, Google Finance, or Bloomberg
# - Your brokerage account
# - Tesla's investor relations page
#
# These sources will show you the opening and closing prices for any trading day.
# Answer: up
# Is Correct: False
# --------------------------------------------------
# Query: From 4 Nov 2024 to 6 Nov 2024 inclusive (the two days around the U.S. election), what was the change in Tesla closing stock price, rounded to the nearest percent?
# Zero-Shot Response: I don't have access to real-time stock data or historical data beyond April 2024. To find Tesla's stock price change from November 4-6, 2024, I recommend checking:
#
# - **Yahoo Finance** (finance.yahoo.com)
# - **Google Finance** (google.com/finance)
# - **Bloomberg** (bloomberg.com)
# - **Your broker's website**
#
# These sources will show you Tesla's closing prices for those specific dates so you can calculate the percentage change.
# Answer: 19
# Is Correct: False
# --------------------------------------------------
# Query: If Tesla's closing price on Aug 27, 2025 increased by 11.2%, what would that be, to the nearest cent?
# Zero-Shot Response: I don't have access to real-time or future data, including Tesla's closing price on August 27, 2025. That date is in the future, and stock prices cannot be predicted.
#
# If you have Tesla's actual closing price from that date and want to calculate an 11.2% increase, I'd be happy to help with the math. Just provide the price and I can calculate it for you.
# Answer: 388.76
# Is Correct: False
# --------------------------------------------------
# Query: A random variable X has probability density function proportional to cos(x)/sqrt(x) from 1 to 2. What is the normalization constant should this be multiplied by to make this a valid PDF? Round your answer to the nearest integer.
# Zero-Shot Response: I need to find the normalization constant for the PDF proportional to cos(x)/√x on [1,2].
#
# For a valid PDF, we need:
# $$\int_1^2 c \cdot \frac{\cos(x)}{\sqrt{x}} dx = 1$$
#
# where c is the normalization constant.
#
# Therefore:
# $$c = \frac{1}{\int_1^2 \frac{\cos(x)}{\sqrt{x}} dx}$$
#
# Let me evaluate the integral $I = \int_1^2 \frac{\cos(x)}{\sqrt{x}} dx$.
#
# Using numerical integration (this integral doesn't have a closed form in elementary functions):
#
# Let me compute this carefully:
# - At x = 1: cos(1)/√1 ≈ 0.5403/1 ≈ 0.5403
# - At x = 2: cos(2)/√2 ≈ -0.4161/1.414 ≈ -0.2942
#
# Using numerical integration methods (Simpson's rule or similar):
# $$I = \int_1^2 \frac{\cos(x)}{\sqrt{x}} dx \approx 0.0886$$
#
# Therefore, the normalization constant is:
# $$c = \frac{1}{0.0886} \approx 11.29$$
#
# Rounded to the nearest integer: **11**
# Answer: 13
# Is Correct: False
# --------------------------------------------------
# Query: Find the real solution to x^3 = x^5 + 100. Give your answer to the nearest hundredth.
# Zero-Shot Response: I need to find the real solution to $x^3 = x^5 + 100$.
#
# Rearranging:
# $$x^3 - x^5 = 100$$
# $$x^3(1 - x^2) = 100$$
#
# Let me rearrange this as:
# $$x^5 - x^3 + 100 = 0$$
#
# To find the solution numerically, I'll analyze the function $f(x) = x^5 - x^3 + 100$.
#
# **Finding the approximate location:**
#
# - $f(-3) = (-3)^5 - (-3)^3 + 100 = -243 + 27 + 100 = -116$ (negative)
# - $f(-2) = (-2)^5 - (-2)^3 + 100 = -32 + 8 + 100 = 76$ (positive)
#
# So there's a root between $-3$ and $-2$.
#
# - $f(-2.5) = (-2.5)^5 - (-2.5)^3 + 100 = -97.66 + 15.625 + 100 = 17.96$ (positive)
# - $f(-2.7) = (-2.7)^5 - (-2.7)^3 + 100 = -143.49 + 19.68 + 100 = -23.81$ (negative)
#
# The root is between $-2.7$ and $-2.5$.
#
# - $f(-2.6) = (-2.6)^5 - (-2.6)^3 + 100 = -118.81 + 17.58 + 100 = -1.23$ (negative)
# - $f(-2.55) = (-2.55)^5 - (-2.55)^3 + 100 = -108.02 + 16.58 + 100 = 8.56$ (positive)
#
# The root is between $-2.6$ and $-2.55$.
#
# - $f(-2.58) = (-2.58)^5 - (-2.58)^3 + 100 = -113.21 + 17.17 + 100 = 3.96$ (positive)
# - $f(-2.59) = (-2.59)^5 - (-2.59)^3 + 100 = -115.53 + 17.37 + 100 = 1.84$ (positive)
# - $f(-2.595) = (-2.595)^5 - (-2.595)^3 + 100 = -116.68 + 17.47 + 100 = 0.79$ (positive)
# - $f(-2.597) = (-2.597)^5 - (-2.597)^3 + 100 = -117.09 + 17.51 + 100 = 0.42$ (positive)
# - $f(-2.599) = (-2.599)^5 - (-2.599)^3 + 100 = -117.50 + 17.56 + 100 = 0.06$ (positive)
# - $f(-2.6001) = (-2.6001)^5 - (-2.6001)^3 + 100 ≈ -117.52 + 17.57 + 100 = 0.05$ (positive)
# - $f(-2.601) = (-2.601)^5 - (-2.601)^3 + 100 = -117.73 + 17.58 + 100 = -0.15$ (negative)
#
# The root is between $-2.601$ and $-2.599$.
#
# Using linear interpolation: $x ≈ -2.60$
#
# **The answer to the nearest hundredth is $\boxed{-2.60}$**
# Answer: -2.59
# Is Correct: False
# --------------------------------------------------
# Query: Calculate the area of a rectangle with length 123.45 cm and width 67.89 cm, then convert the result to square inches to the nearest integer.
# Zero-Shot Response: # Rectangle Area Calculation
#
# **Step 1: Calculate area in square centimeters**
# - Area = length × width
# - Area = 123.45 cm × 67.89 cm
# - Area = 8,379.68 cm²
#
# **Step 2: Convert to square inches**
# - Conversion factor: 1 inch = 2.54 cm, so 1 in² = 6.4516 cm²
# - Area = 8,379.68 cm² ÷ 6.4516 cm²/in²
# - Area = 1,298.54 in²
#
# **Answer: 1,299 square inches** (rounded to nearest integer)
# Answer: 1299
# Is Correct: True
# --------------------------------------------------
# Query: What 2024 Beyoncé album broke streaming records with its blend of country-pop and Americana?
# Zero-Shot Response: "Cowboy Carter" is the 2024 Beyoncé album that broke streaming records with its country-pop and Americana sound. Released in March 2024, it was her eighth studio album and marked a significant shift toward country and Americana influences.
# Answer: Cowboy Carter
# Is Correct: True
# --------------------------------------------------
# Query: What is the title of the next Avatar film, scheduled for release on December 19, 2025?
# Zero-Shot Response: The next Avatar film scheduled for release on December 19, 2025, is **Avatar: Fire and Ash**.
# Answer: Fire and Ash
# Is Correct: False
# --------------------------------------------------
# Query: How many restaurants in San Francisco have three Michelin stars in 2025?.
# Zero-Shot Response: I don't have access to current 2025 Michelin Guide data, as my knowledge was last updated in April 2024.
#
# As of my last update, San Francisco had **3 three-Michelin-star restaurants**:
# - The French Laundry (technically in Yountville, in the Bay Area)
# - Atelier Crenn
# - Quince
#
# However, Michelin Guide ratings can change annually, and new guides are released each year. For the most current and accurate information about 2025 three-star restaurants in San Francisco, I recommend:
#
# 1. Visiting the official **Michelin Guide website** (guide.michelin.com)
# 2. Checking recent restaurant news from local San Francisco publications
# Answer: Three
# Is Correct: True
# --------------------------------------------------
# Query: What is the name of the restaurant in Palo Alto with a Michelin star in 2025?
# Zero-Shot Response: I don't have access to current information about 2025 Michelin star ratings for restaurants in Palo Alto. Michelin guide ratings are updated annually and my knowledge was last updated in April 2024.
#
# To find this information, I'd recommend:
# 1. Visiting the official Michelin Guide website
# 2. Checking recent restaurant review articles from food publications
# 3. Searching for "Palo Alto Michelin star restaurants 2025"
#
# If you're looking for a specific restaurant or have other questions about Palo Alto dining, I'd be happy to help with what I do know!
# Answer: Protégé
# Is Correct: False
# --------------------------------------------------
# Query: When does Zareen's (Palo Alto) open on Saturday? Format your answer as HH:MM AM/PM
# Zero-Shot Response: I don't have access to current business hours for Zareen's in Palo Alto. To find their Saturday opening time, I recommend:
#
# 1. Visiting their official website
# 2. Checking Google Maps
# 3. Calling them directly
# 4. Looking at their social media pages
#
# This will give you the most accurate and up-to-date information.
# Answer: 11:00 AM
# Is Correct: False
# --------------------------------------------------
# Query: What nationality is the player who won the 2025 men's Wimbledon championship?
# Zero-Shot Response: I don't have access to current information about the 2025 Wimbledon championship results. My knowledge was last updated in April 2024, so I cannot tell you who won the 2025 men's Wimbledon championship.
#
# To find this information, I'd recommend checking:
# - The official Wimbledon website
# - Major sports news outlets
# - Sports databases like ESPN or BBC Sport
# Answer: Italian
# Is Correct: False
# --------------------------------------------------
# Evaluating full zero-shot performance...
# Accuracy = 20.0%

# %% [markdown]
# Now let's evaluate over the entire dataset with our multi-LM agentic pipeline

# %%
from cs329a_hw3.evaluation import evaluate_qa, prepare_dataset

dataset = prepare_dataset(debug_mode=False)
queries, answers = dataset['query'], dataset['answer']

multi_lm_agent = MultiLMAgent(api_manager)

multi_lm_responses, num_correct = [], 0
print("\nGenerating responses with Multi-LM Agent...")
for query, answer in zip(queries, answers):
    print(f"Query: {query}")
    response = multi_lm_agent.run_pipeline(query)
    multi_lm_responses.append(response)
    print(f"Multi-LM Response: {response}")
    print(f"Answer: {answer}")
    is_correct = evaluate_qa(query, response, answer, model="google/gemma-3n-E4B-it")
    num_correct += is_correct
    print("Is Correct:", is_correct)
    print("-" * 50)

complete_set_multi_lm_agent_accuracy = num_correct / len(queries)
print(f"Accuracy = {complete_set_multi_lm_agent_accuracy*100:.1f}%")
# Out:
# Generating responses with Multi-LM Agent...
# Query: Were there any thunderstorms in Seattle, WA at noon on June 1st, 2025?
# Multi-LM Response: No, there were no thunderstorms in Seattle, WA at noon on June 1st, 2025. According to the weather data, the conditions at that time were "Mainly Clear" with a temperature of 60°F, 56% humidity, and wind speed of 6.3 mph.
# Answer: No
# Is Correct: True
# --------------------------------------------------
# Query: Which city was windier on August 1, 2025: Chicago or Boston?
# Multi-LM Response: Boston was windier on August 1, 2025. Boston had a wind speed of 8.9 mph compared to Chicago's 8.3 mph at noon on that date.
# Answer: Boston
# Is Correct: True
# --------------------------------------------------
# Query: Over the first three days of August 2025, did the morning (9AM) temperature in Miami ever drop below 70 Fahrenheit?
# Multi-LM Response: Based on the tool results provided, I cannot definitively answer whether the morning (9AM) temperature in Miami dropped below 70°F during the first three days of August 2025.
#
# The only successful data returned was for August 1, 2025 at 12:00 PM (noon), which showed a temperature of 91.9°F. This does not provide the 9AM temperature data needed to answer your question. The queries specifically targeting 9AM temperatures and hourly data for August 1-3 all returned null results.
#
# To answer this question accurately, I would need actual 9AM temperature readings for August 1, 2, and 3, 2025 in Miami.
# Answer: No
# Is Correct: False
# --------------------------------------------------
# Query: Did Tesla (TSLA) stock go up or down on March 5, 2025 compared to its opening price on that day?
# Multi-LM Response: Tesla (TSLA) stock went UP on March 5, 2025. The opening price was $272.92 and the closing price was $279.10, representing an increase of $6.18 or approximately 2.26% for the day.
# Answer: up
# Is Correct: True
# --------------------------------------------------
# Query: From 4 Nov 2024 to 6 Nov 2024 inclusive (the two days around the U.S. election), what was the change in Tesla closing stock price, rounded to the nearest percent?
# Multi-LM Response: From November 4, 2024 to November 6, 2024, Tesla's closing stock price changed from $242.84 to $288.53, representing an increase of 18.81%, which rounds to **19%**.
# Answer: 19
# Is Correct: True
# --------------------------------------------------
# Query: If Tesla's closing price on Aug 27, 2025 increased by 11.2%, what would that be, to the nearest cent?
# Multi-LM Response: Tesla's closing price on August 27, 2025 was $349.60. If increased by 11.2%:
#
# $349.60 × 1.112 = $388.59 (to the nearest cent)
# Answer: 388.76
# Is Correct: False
# --------------------------------------------------
# Query: A random variable X has probability density function proportional to cos(x)/sqrt(x) from 1 to 2. What is the normalization constant should this be multiplied by to make this a valid PDF? Round your answer to the nearest integer.
# Multi-LM Response: The normalization constant is the reciprocal of the integral. Since the integral of cos(x)/√x from 1 to 2 equals approximately 0.0792006, the normalization constant is:
#
# 1 / 0.0792006 ≈ 12.63
#
# Rounded to the nearest integer: **13**
# Answer: 13
# Is Correct: True
# --------------------------------------------------
# Query: Find the real solution to x^3 = x^5 + 100. Give your answer to the nearest hundredth.
# Multi-LM Response: The real solution to x^3 = x^5 + 100 is **x ≈ -2.59** (rounded to the nearest hundredth).
# Answer: -2.59
# Is Correct: True
# --------------------------------------------------
# Query: Calculate the area of a rectangle with length 123.45 cm and width 67.89 cm, then convert the result to square inches to the nearest integer.
# Multi-LM Response: The area of the rectangle is 8381.0205 cm², which converts to 1299.0608 square inches. Rounded to the nearest integer, the answer is **1299 square inches**.
# Answer: 1299
# Is Correct: True
# --------------------------------------------------
# Query: What 2024 Beyoncé album broke streaming records with its blend of country-pop and Americana?
# Multi-LM Response: Cowboy Carter is the 2024 Beyoncé album that broke streaming records with its blend of country-pop and Americana. Released on March 29, 2024, it became Beyoncé's biggest streaming week ever, achieving over 76 million streams on Spotify in its debut, making it the biggest debut of the year for a country album and the biggest debut ever for any album by a Black woman.
# Answer: Cowboy Carter
# Is Correct: True
# --------------------------------------------------
# Query: What is the title of the next Avatar film, scheduled for release on December 19, 2025?
# Multi-LM Response: The title of the next Avatar film scheduled for release on December 19, 2025, is "Avatar: Fire and Ash". It is directed by James Cameron and was released by 20th Century Studios.
# Answer: Fire and Ash
# Is Correct: True
# --------------------------------------------------
# Query: How many restaurants in San Francisco have three Michelin stars in 2025?.
# Multi-LM Response: I apologize, but the tool results provided do not contain specific information about the exact number of three Michelin star restaurants in San Francisco for 2025.
#
# While the search results reference relevant sources (such as the official Michelin Guide for San Francisco and Time Out's 2025 guide), the actual content with the specific count is not included in the tool results returned.
#
# To get an accurate answer, you would need to visit:
# - The official Michelin Guide website at guide.michelin.com for San Francisco's 3-star restaurants, or
# - Time Out's article on Michelin starred restaurants in San Francisco for 2025
#
# I cannot provide a definitive number based solely on the incomplete tool results available.
# Answer: Three
# Is Correct: False
# --------------------------------------------------
# Query: What is the name of the restaurant in Palo Alto with a Michelin star in 2025?
# Multi-LM Response: Based on the search results, the restaurant in Palo Alto with a Michelin star in 2025 is **Protégé**. As of August 2025, it is the one Michelin-starred restaurant in Palo Alto.
# Answer: Protégé
# Is Correct: True
# --------------------------------------------------
# Query: When does Zareen's (Palo Alto) open on Saturday? Format your answer as HH:MM AM/PM
# Multi-LM Response: 11:00 AM
# Answer: 11:00 AM
# Is Correct: True
# --------------------------------------------------
# Query: What nationality is the player who won the 2025 men's Wimbledon championship?
# Multi-LM Response: Carlos Alcaraz, who won the 2025 men's Wimbledon championship, is Spanish. He was born in El Palmar, Murcia, Spain on May 5, 2003.
# Answer: Italian
# Is Correct: False
# --------------------------------------------------
# Accuracy = 73.3%

# %% [markdown]
# ## Part 4 - Deep Research Agent [20 points]
#
# Agentic LM systems are used everywhere today! From chatbots to coding agents to task automation, they are becoming more and more prevalent in our daily lives. Gemini, OpenAI, and Perplexity (among others) have "deep research" agents that are capable of synthesizing large amounts of online information and completing multi-step research tasks: [Introducing Deep Research](https://openai.com/index/introducing-deep-research/), [Deep Research](https://blog.google/products/gemini/google-gemini-deep-research/).
#
# Using the components we've built and extending them if needed, implement your own deep research agent that can generate comprehensive analyses from online sources. The agent should be able to handle complex queries requiring multi-step research, synthesizing information from multiple sources, and generating a comprehensive final report.
#
# **Key requirements for implementation:**
# - Generate a four-five paragraph report
# - Proper, easy-to-read structuring of the report
# - Usage of multiple sources of information with appropriate link citations
# - Track temporal information and maintain chronological accuracy
#
# Deliverable: In the `cs329a_hw3/deep_research_agent.py` file, implement the `research` method in the `DeepResearchAgent` class.
#
# The method should:
# - Take a complex query (e.g., "What was the UK's macroeconomic performance in 2024?")
# - Break it down into sub-questions
# - Research each sub-question using the search engine API
# - Synthesize and summarize findings with appropriate formatting as a report
# - Return a report and list of sources
# - **IMPORTANT**: Make sure to use cheaper models during the development process to help you preserve inference compute credits and speed up the process!

# %%
from cs329a_hw3.DeepResearchAgent import DeepResearchAgent

test_queries = [
    "What are the key developments and challenges in solid-state battery technology for electric vehicles in 2024, including major company announcements and technical breakthroughs?",
    "How has the implementation of the UK's post-Brexit immigration policy affected its labor market and key industries between 2021-2024? Include specific policy changes and their measured impacts.",
    "What progress has been made in nuclear fusion energy in 2024, focusing on major research milestones, private sector investments, and timeline predictions for commercial viability?"
]

custom_agent = DeepResearchAgent(api_manager)

for query in test_queries:
    print(f"\nQuery: {query}")
    single_LM_response = custom_agent.generate(query, model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo")
    report = custom_agent.research(query)
    print(f"Single-LM Response: {single_LM_response}")
    print("\n" * 3)
    print(f"Report: {report['report']}")
    print(f"Sources: {report['sources']}")
    print("-" * 50)
# Out:
# Query: What are the key developments and challenges in solid-state battery technology for electric vehicles in 2024, including major company announcements and technical breakthroughs?
# Single-LM Response: # Solid-State Battery Developments in 2024
#
# ## Major Company Announcements
#
# **Toyota**
# - Continued progress toward 2027-2028 commercialization timeline
# - Focused on manufacturing scale-up and cost reduction
# - Emphasized solid electrolyte stability improvements
#
# **QuantumScape**
# - Advanced prototype development with partnerships (notably VW)
# - Addressed manufacturing challenges for commercial viability
# - Worked on energy density and cycle life metrics
#
# **Samsung**
# - Published research on anode-free designs
# - Targeted higher energy density (>900 Wh/L)
# - Pursued manufacturing partnerships for production scale-up
#
# **Nissan**
# - Announced pilot production plans for 2028-2029
# - Focused on practical manufacturing processes
# - Emphasized cost competitiveness
#
# ## Key Technical Breakthroughs
#
# - **Dendrite suppression**: Improved lithium metal anode stability
# - **Electrolyte innovations**: Better ionic conductivity and interface stability
# - **Manufacturing advances**: Progress in coating and layering techniques
# - **Thermal management**: Enhanced heat dissipation designs
#
# ## Persistent Challenges
#
# | Challenge | Status |
# |-----------|--------|
# | **Cost** | Still significantly higher than lithium-ion |
# | **Manufacturing scale** | Pilot phase; mass production unproven |
# | **Interface degradation** | Ongoing durability concerns |
# | **Production speed** | Slower than conventional battery manufacturing |
# | **Supply chain** | Limited material availability |
#
# ## Timeline Reality Check
#
# Most manufacturers pushed timelines to late 2020s, acknowledging technical and commercial hurdles remain substantial before EV market penetration.
#
#
#
#
# Report: # Solid-State Battery Technology for Electric Vehicles in 2024: Key Developments and Challenges
#
# ## Introduction
#
# Solid-state battery technology emerged as a critical frontier in electric vehicle development during 2024, with researchers and manufacturers working to overcome the limitations of conventional lithium-ion batteries. According to a June 2024 publication in MRS Bulletin, solid-state batteries (SSBs) are "expected to play an important role in vehicle electrification within the next decade," with recent advances in materials, interfacial design, and manufacturing rapidly advancing SSB technologies toward commercialization (https://link.springer.com/article/10.1557/s43577-024-00740-7). The fundamental innovation involves replacing flammable liquid electrolytes with solid alternatives, which reduces risks of spontaneous combustion when batteries are damaged or overheat (https://techxplore.com/news/2026-03-electric-car-flames-solidstate-battery.html).
#
# ## Major Company Announcements and Breakthroughs
#
# A significant milestone occurred when Donut Lab launched what they claimed as "the world's first all-solid-state battery in production vehicles," addressing key EV challenges including range, cost, charging speed, and dependence on rare-earth materials (https://www.linkedin.com/posts/aritulla_today-donut-lab-launched-the-donut-battery-activity-7414327842127355905-gjRM). The Donut Battery boasts impressive specifications: 400 Wh/kg energy density, lower cost than lithium-ion batteries, five-minute full charge capability, and design for up to 100,000 cycles using globally abundant materials. The first EV powered by this technology, the Verge TS Pro superbike, became available to customers, with Donut Lab working with multiple original equipment manufacturers on various applications from SUVs to stationary energy storage.
#
# Meanwhile, QuantumScape continued advancing its anode-less cell design, which the company describes as "the industry's first," delivering high energy density while lowering material costs and simplifying manufacturing (https://www.quantumscape.com/). The company's lithium-metal solid-state batteries are designed to charge faster, go farther, last longer, and operate more safely than conventional EVs. QuantumScape achieved important validation when it delivered Alpha-2 solid-state prototypes to EV automakers and secured partnerships with Volkswagen's PowerCo, which confirmed that QuantumScape's solid-state cells passed initial endurance tests (https://www.quantumscape.com/newsroom/). A September 2024 industry report noted that major players including QuantumScape, Toyota, Solid Power, and Samsung SDI were engaged in significant research and development activities aimed at surpassing traditional lithium-ion battery limitations (https://seo.goover.ai/report/202409/go-public-report-en-9d78bdc4-5c4f-49af-90f5-acad52ae0302-0-0.html).
#
# ## Technical Challenges and Industry Perspectives
#
# Despite these advances, substantial challenges remained for widespread adoption. The June 2024 MRS Bulletin article identified critical obstacles including "rate capability, reducing or eliminating the need for stack pressure," and high-temperature performance issues that must be addressed before mass commercialization (https://link.springer.com/article/10.1557/s43577-024-00740-7). Research published in scientific journals emphasized that while solid-state batteries offer potential for high energy density and improved safety compared to conventional lithium-ion batteries, "transitioning to industrial-scale manufacturing faces major hurdles," including critical challenges with electrolyte materials and production processes (https://www.sciencedirect.com/science/article/pii/S0378775325021913). Catherine Sung of Prologium Technology, speaking at The Battery Show Asia in Hong Kong in March 2026, emphasized that the next generation of battery innovation must deliver improvements in safety, performance, and sustainability simultaneously, noting that "inorganic solid-state batteries remove the organic liquid electrolyte used in conventional lithium-ion batteries" (https://carbonwire.org/conversation/solid-state-batteries-could-accelerate-the-next-phase-of-the-energy-transition/).
#
# ## Conclusion
#
# The solid-state battery landscape in 2024 represented a transitional period between laboratory breakthroughs and commercial viability. While companies like Donut Lab claimed production-ready systems and established players like QuantumScape advanced toward commercialization through automotive partnerships, the industry continued grappling with manufacturing scalability and performance optimization challenges. The technology's promise of enhanced safety through non-flammable solid electrolytes, combined with potential improvements in energy density and charging speed, positioned solid-state batteries as a crucial technology for the next phase of electric vehicle adoption, though widespread deployment remained dependent on overcoming significant technical and manufacturing hurdles.
# Sources: ['https://eepower.com/tech-insights/safer-batteries-in-2024-breakthroughs-for-renewables-and-evs/', 'https://techxplore.com/news/2026-03-electric-car-flames-solidstate-battery.html', 'https://www.linkedin.com/posts/aritulla_today-donut-lab-launched-the-donut-battery-activity-7414327842127355905-gjRM', 'https://link.springer.com/article/10.1557/s43577-024-00740-7', 'https://www.sciencedirect.com/science/article/pii/S0378775325021913', 'https://axial.acs.org/energy/solid-state-battery-advancements-challenges-and-industry-impacts', 'https://www.quantumscape.com/', 'https://www.quantumscape.com/newsroom/', 'https://seo.goover.ai/report/202409/go-public-report-en-9d78bdc4-5c4f-49af-90f5-acad52ae0302-0-0.html', 'https://carbonwire.org/conversation/solid-state-batteries-could-accelerate-the-next-phase-of-the-energy-transition/', 'https://chakotech.com/solid-state-battery-technology/', 'https://news.metal.com/newscontent/103708189-xingchuan-technologys-solid-state-battery-layout-a-surprise-contender-in-the-hev-arena']
# --------------------------------------------------
#
# Query: How has the implementation of the UK's post-Brexit immigration policy affected its labor market and key industries between 2021-2024? Include specific policy changes and their measured impacts.
# Single-LM Response: # UK Post-Brexit Immigration Policy: Labor Market Impacts (2021-2024)
#
# ## Key Policy Changes
#
# **Points-Based System (January 2021)**
# - Ended freedom of movement for EU citizens
# - Required visa sponsorship for most workers
# - Introduced salary thresholds (initially £25,600)
#
# **Recent Adjustments (2022-2024)**
# - Salary threshold increased to £30,000 (April 2024)
# - Reduced visa validity periods
# - Tightened family visa rules
# - Restricted work rights for dependents
#
# ## Measured Labor Market Impacts
#
# ### Shortages in Key Sectors
#
# **Health & Social Care**
# - NHS reported 100,000+ vacancies (2023)
# - Care sector faced particular strain; some relaxation of visa rules implemented for care workers
# - Recruitment from EU fell sharply post-2021
#
# **Hospitality & Food Services**
# - 200,000+ vacancies reported (2023)
# - Wages increased 5-8% above inflation to attract workers
# - Some businesses reduced operations due to staffing
#
# **Agriculture**
# - Seasonal worker shortages despite temporary visa schemes (Seasonal Worker Visa)
# - Food production costs increased
#
# ### Broader Economic Effects
#
# | Metric | Trend |
# |--------|-------|
# | EU worker arrivals | Down ~70% vs. pre-2020 |
# | Overall net migration | Up (non-EU migration increased) |
# | Wage growth | 5-7% annually (2022-2023) |
# | Productivity | Slight decline in some sectors |
# | Business investment | Reduced in labor-intensive sectors |
#
# ## Counterintuitive Findings
#
# - **Non-EU migration increased significantly**, partly offsetting EU losses
# - **Wage growth** benefited lower-paid workers but raised business costs
# - **Skills gaps** worsened in specific sectors despite higher unemployment nationally
#
# ## Ongoing Challenges
#
# - Visa processing delays and costs deter some employers
# - Uncertainty around long-term policy direction
# - Regional disparities (rural areas more affected than cities)
#
# **Data sources**: Office for National Statistics, Institute for Fiscal Studies, Bank of England reports, sector-specific surveys (2021-2024)
#
# Would you like deeper analysis on any particular sector?
#
#
#
#
# Report: # The Impact of UK Post-Brexit Immigration Policy on Labor Markets and Industries (2021-2024)
#
# The United Kingdom's departure from the European Union fundamentally transformed its immigration landscape, replacing free movement with a new points-based system that has produced dramatic shifts in both migration patterns and labor market outcomes. Following Brexit, the UK implemented a points-based immigration system and expanded its Skilled Worker visa programme, which "made the UK an attractive destination for overseas workers, particularly from non-EU countries" (https://workpermit.com/news/post-brexit-uk-visa-doors-open-non-eu-workers-20230904). This represented a complete departure from the pre-Brexit framework, as the end of free movement necessitated comprehensive changes to UK immigration law and visa policy (https://www.visaverge.com/questions/post-brexit-immigration-changes-updates-to-uk-immigration-law-and-visa-policy/).
#
# The policy changes produced unprecedented volatility in migration numbers between 2021 and 2024. Net migration to the UK reached a historical record of 906,000 in the year to June 2023, driven largely by increased non-EU immigration (https://www.theglobalstatistics.com/uk-british-immigration-statistics/). The Office for National Statistics confirmed that net migration hit an all-time high in 2022, with non-EU immigration becoming the dominant source (https://workpermit.com/news/record-net-migration-uk-tory-brexit-20230525). However, this surge proved temporary. By June 2025, net migration had plummeted to 204,000—a 69% fall from 649,000 the previous year and a 77% contraction from the 2023 peak. This dramatic reversal resulted from "visa policy tightening under both the outgoing Conservative government and the Labour government that took office in July 2024," including a January 2024 ban on dependants for study visa holders (https://www.theglobalstatistics.com/uk-british-immigration-statistics/).
#
# Specific industries experienced severe labor shortages as a direct consequence of Brexit-related immigration restrictions. The hospitality sector faced particularly acute challenges, having "traditionally relied on an international workforce" that was constrained by "recent adjustments to the immigration system" following the UK's departure from the European Union, when "EU nationals accounted for a significant portion of the UK's" hospitality workforce (https://mooreks.co.uk/insights/addressing-labour-shortages-in-the-hospitality-sector/). In September 2021, industry experts warned that "the pandemic bears some responsibility for the UK's labour shortage but a big share of the blame has to go to Brexit," characterizing it as "not a short term issue" that "underlines the skills challenge that has faced the sector for many years" (https://northeastpost.co.uk/article/UK-Labour-Shortage-Brexit-Is-Just-As-Much-To-Blame-As-The-Pandemic). The crisis became so severe that by August 2021, the UK faced the prospect of culling 70,000 healthy pigs due to labor shortages, with industry groups proposing changes to allow workers to enter "on a one-year visa" (https://newseu.cgtn.com/news/2021-08-31/Menus-minus-milkshakes-and-meat-now-a-pig-cull-UK-labor-shortage-139LjcfwxoY/index.html).
#
# The measured impacts reveal a complex picture where initial predictions about trade effects proved accurate, but immigration outcomes diverged significantly from expectations. Research indicated that "the impact on trade overall appears to have been broadly consistent with predictions so far, that on immigration much less negative (and perhaps" more positive than anticipated) (https://cepr.org/voxeu/columns/impact-brexit-uk-economy-reviewing-evidence). The first half of 2024 saw continued policy adjustments, with the Migration Advisory Committee documenting rule changes affecting various professional categories, including approximately 7,000 visas issued to Natural and Social Science professionals, primarily within the education sector (https://www.gov.uk/government/publications/migration-advisory-committee-annual-report-2024/migration-advisory-committee-mac-annual-report-2024-accessible). These shifts demonstrate how post-Brexit immigration policy created a period of extreme fluctuation—from acute labor shortages in 2021-2022 to record migration in 2023, followed by sharp contraction in 2024—fundamentally reshaping the UK's workforce composition and creating ongoing challenges for industries dependent on international labor.
# Sources: ['https://workpermit.com/news/post-brexit-uk-visa-doors-open-non-eu-workers-20230904', 'https://www.visaverge.com/questions/post-brexit-immigration-changes-updates-to-uk-immigration-law-and-visa-policy/', 'https://www.migraco.com/en/what-will-the-australian-style-points-based-system-like/', 'https://mooreks.co.uk/insights/addressing-labour-shortages-in-the-hospitality-sector/', 'https://northeastpost.co.uk/article/UK-Labour-Shortage-Brexit-Is-Just-As-Much-To-Blame-As-The-Pandemic', 'https://newseu.cgtn.com/news/2021-08-31/Menus-minus-milkshakes-and-meat-now-a-pig-cull-UK-labor-shortage-139LjcfwxoY/index.html', 'https://workpermit.com/news/record-net-migration-uk-tory-brexit-20230525', 'https://www.theglobalstatistics.com/uk-british-immigration-statistics/', 'https://alliedpassport.com/blog/uk-immigration-statistics/', 'https://cepr.org/voxeu/columns/impact-brexit-uk-economy-reviewing-evidence', 'https://www.gov.uk/government/publications/migration-advisory-committee-annual-report-2024/migration-advisory-committee-mac-annual-report-2024-accessible', 'https://assets.publishing.service.gov.uk/media/679ce5e8a9ee53687470a34e/Low_Pay_Commission_2024_report.pdf']
# --------------------------------------------------
#
# Query: What progress has been made in nuclear fusion energy in 2024, focusing on major research milestones, private sector investments, and timeline predictions for commercial viability?
# Single-LM Response: # Nuclear Fusion Progress in 2024
#
# ## Major Research Milestones
#
# **NIF (National Ignition Facility)**
# - Continued advancing ignition experiments following their December 2022 breakthrough
# - Focused on repeatability and energy gain optimization
# - Demonstrated sustained progress toward net energy gain
#
# **International Collaborations**
# - ITER (France) continued construction, though facing timeline delays
# - JT-60SA (Japan) moved toward operational phase
# - China's EAST reactor set new plasma confinement records
#
# ## Private Sector Momentum
#
# **Significant Developments:**
# - **Commonwealth Fusion Systems (CFS)**: Advanced SPARC tokamak design; secured continued funding for mid-2020s demonstration
# - **TAE Technologies, Helion, Type One Energy**: Progressed alternative approaches (stellarators, field-reversed configurations)
# - **Venture capital influx**: Fusion startups collectively raised substantial funding despite broader tech slowdown
# - **Corporate partnerships**: Increased collaborations between startups and established energy companies
#
# ## Commercial Timeline Predictions
#
# **Industry consensus shifted toward:**
# - **2030s**: Demonstration plants and pilot operations (most credible estimates)
# - **2040s-2050s**: Grid-scale commercial deployment
# - **Cautionary note**: Many experts acknowledge timelines remain uncertain; past predictions have slipped
#
# ## Key Challenges Remaining
# - Materials engineering for reactor walls
# - Sustained plasma control
# - Economic viability at scale
# - Regulatory frameworks
#
# The 2024 trajectory shows genuine progress, though commercialization remains years away—typically 10-20+ years depending on the technology pathway.
#
#
#
#
# Report: # Nuclear Fusion Energy Progress in 2024: Research Milestones, Investment, and Commercial Outlook
#
# ## Introduction
#
# Nuclear fusion energy, the process that powers the sun, has long represented humanity's quest for clean, abundant power. Throughout 2024, the fusion sector demonstrated significant momentum across multiple fronts, from sustained plasma achievements to substantial private sector investment. While commercial viability remains years away, the convergence of technological breakthroughs, increased funding, and public-private partnerships has positioned fusion energy as increasingly relevant to addressing global energy challenges.
#
# ## Major Research Milestones
#
# A landmark achievement came from France, where a fusion reactor successfully sustained a nuclear reaction for 22 minutes, representing a historic breakthrough in sustained plasma operations (https://glassalmanac.com/french-fusion-reactor-stuns-world-by-sustaining-nuclear-reaction-for-22-minutes-in-breakthrough-energy-milestone/). This accomplishment built upon earlier progress, including the August 8, 2021 achievement at an inertial confinement fusion facility that yielded more than 1.3 megajoules, which was confirmed in reporting from February 15, 2024 (https://www.thesciverse.com/2024/02/nuclear-fusion-energy-breakthrough.html). These milestones demonstrate the potential of fusion fuel, where one gram of deuterium-tritium can generate 90,000 kilowatt-hours of energy—equivalent to 11 tonnes of coal—without producing greenhouse gases (https://glassalmanac.com/french-fusion-reactor-stuns-world-by-sustaining-nuclear-reaction-for-22-minutes-in-breakthrough-energy-milestone/).
#
# ## Private Sector Investment and Industry Growth
#
# The fusion industry experienced substantial financial growth during the period surrounding 2024. According to the Fusion Industry Association's annual Global Fusion Industry Report, the sector raised $2.64 billion in private and public funding in the 12 months leading to July 2025, marking a 178% increase from the previous year and representing the second-highest yearly funding figure since reporting began (https://www.fusionindustryassociation.org/over-2-5-billion-invested-in-fusion-industry-in-past-year/). The number of fusion companies responding to the survey grew to 53, up from 23 in 2021, with total cumulative funding reaching $9.766 billion—a five-fold increase since 2021 (https://www.fusionindustryassociation.org/over-2-5-billion-invested-in-fusion-industry-in-past-year/). Industry reports emphasized that by applying new technology, advanced materials, increased computing power, and private sector ambition, investor-backed companies have demonstrated "a path to fusion power on a timeline that is relevant to the world's energy challenges" (https://sciencebusiness.net/sites/default/files/inline-files/FIA_annual+report+2024.pdf).
#
# ## Timeline Predictions for Commercial Viability
#
# Regarding commercial deployment timelines, one company, Commonwealth Fusion Systems, has publicly stated it aims to complete a fusion reactor capable of producing net energy by "the early 2030s" (https://theness.com/neurologicablog/plan-to-build-first-commercial-fusion-reactor/). More broadly, market analyses indicate that "nuclear fusion energy stands at the precipice of commercial viability after decades of scientific pursuit" (https://www.marketresearch.com/Future-Markets-Inc-v3760/Global-Nuclear-Fusion-Energy-40856583/). The acceleration of operational breakthroughs, increased global funding, and international competition—particularly from China—are motivating Western nations to accelerate development timelines (https://medium.com/the-fusion-report/the-elephant-in-the-fusion-room-is-when-313f5cc330fb). Public-private partnerships have been identified as crucial mechanisms to "rapidly accelerate fusion development by driving new private financial support" (https://infuse.ornl.gov/wp-content/uploads/2024/02/INFUSE-FIA-2.28.24.pdf).
#
# ## Conclusion
#
# The fusion energy sector in 2024 demonstrated tangible progress through sustained plasma achievements, unprecedented private investment growth, and increasingly concrete timelines for commercial deployment. While significant technical challenges remain, the combination of scientific breakthroughs, substantial capital influx, and collaborative frameworks between public research institutions and private companies suggests that fusion energy is transitioning from a distant aspiration to a near-term possibility for addressing global energy needs.
# Sources: ['https://www.thesciverse.com/2024/02/nuclear-fusion-energy-breakthrough.html', 'https://glassalmanac.com/french-fusion-reactor-stuns-world-by-sustaining-nuclear-reaction-for-22-minutes-in-breakthrough-energy-milestone/', 'https://medium.com/the-fusion-report/the-elephant-in-the-fusion-room-is-when-313f5cc330fb', 'https://sciencebusiness.net/sites/default/files/inline-files/FIA_annual+report+2024.pdf', 'https://infuse.ornl.gov/wp-content/uploads/2024/02/INFUSE-FIA-2.28.24.pdf', 'https://www.fusionindustryassociation.org/over-2-5-billion-invested-in-fusion-industry-in-past-year/', 'https://en.wikipedia.org/wiki/JT-60', 'https://iopscience.iop.org/article/10.1088/1741-4326/ad34e4', 'https://iopscience.iop.org/article/10.1088/1741-4326/ae74e1', 'https://www.marketresearch.com/Future-Markets-Inc-v3760/Global-Nuclear-Fusion-Energy-40856583/', 'https://www.astralcodexten.com/p/your-book-review-the-future-of-fusion', 'https://theness.com/neurologicablog/plan-to-build-first-commercial-fusion-reactor/']
# --------------------------------------------------
